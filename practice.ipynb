# %%
import pandas as pd
import numpy as np

company_df = pd.read_csv('EXAM_DATA_COMPANY.csv')
person_df = pd.read_csv('EXAM_DATA_PERSON.csv')
transact_df = pd.read_csv('EXAM_DATA_TRANSACT.csv')

display(company_df.head())
display(person_df.head())
display(transact_df.head())
# Out:
#                     address                          company market_cap  \
# 0    74409 La Follette Hill                  Botsford-Dooley     $3.32B
# 1          4 Kropf Crossing   Buckridge, Conroy and Nitzsche    $93.98M
# 2       34952 Badeau Street  Hegmann, Emmerich and O'Connell    $34.63M
# 3  876 Golf Course Junction          Littel, Rau and Kuhlman        NaN
# 4     913 Ludington Parkway                Becker-Macejkovic        NaN
#
#                              industry state        country country_code  \
# 0              Oil Refining/Marketing   NaN         Taiwan           TW
# 1               Major Pharmaceuticals    NY  United States           US
# 2          Medical/Dental Instruments   NaN          China           CN
# 3  Department/Specialty Retail Stores   OAX         Mexico           MX
# 4                                 NaN   NaN          China           CN
#
#   stock_symbol            time_zone
# 0          BCO          Asia/Taipei
# ...

# %%
company_df.describe(include= []).loc['count']
# Out:
# ADDRESS         200
# COMPANY         200
# MARKET_CAP      165
# INDUSTRY        152
# STATE            53
# COUNTRY         200
# COUNTRY_CODE    200
# STOCK_SYMBOL    200
# TIME_ZONE       200
# Name: count, dtype: object

# %%
person_df.head()
# Out:
#   first_name   last_name                        email gender suffix  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
# 3   Marrilee       Burtt              mburtt3@nps.gov      F     Sr
# 4        Ava    Burchett        aburchett4@taobao.com      F    NaN
#
#        title                     address                department  \
# 0         Dr              98557 2nd Pass                  Services
# 1        Rev                7 Marcy Lane                Accounting
# 2  Honorable       57666 Stoughton Court           Human Resources
# 3        NaN             074 Elgar Point  Research and Development
# 4  Honorable  76045 Mockingbird Crossing                  Services
#
#                       bitcoin_address                        company  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp     Lehner, Willms and McClure
# ...

# %%
pdf = person_df
pdf.dtypes
pdf.dtypes
# Out:
# first_name         object
# last_name          object
# email              object
# gender             object
# suffix             object
# title              object
# address            object
# department         object
# bitcoin_address    object
# company            object
# ssn                object
# employee_start     object
# country_code       object
# dtype: object

# %%
pdf['last_name'].head()
pdf['first_name'].head()
# Out:
# 0       Weber
# 1     Grethel
# 2      Wilmar
# 3    Marrilee
# 4         Ava
# Name: first_name, dtype: object

# %%
pdf[['first_name', 'last_name']].head()
pdf[['last_name', 'first_name']].head()
# Out:
#     last_name first_name
# 0  Massenhove      Weber
# 1       Boyce    Grethel
# 2     Duester     Wilmar
# 3       Burtt   Marrilee
# 4    Burchett        Ava

# %%
pdf[0:2]
pdf[0:3]
# Out:
#   first_name   last_name                        email gender suffix  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
#
#        title                address       department  \
# 0         Dr         98557 2nd Pass         Services
# 1        Rev           7 Marcy Lane       Accounting
# 2  Honorable  57666 Stoughton Court  Human Resources
#
#                       bitcoin_address                      company  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp   Lehner, Willms and McClure
# 1  18c1EisbFW7PrRyXoZcztY2oRUuUcnJ2hK  Boehm, VonRueden and Turner
# 2  1DuQgLuydME3HtXrYtDm6xk8agNqozhzs9     Harris, Abbott and O'Kon
#
#            ssn       employee_start country_code
# 0  527-63-1710  2021-02-02 03:48:49           ID
# 1  696-71-8117  2020-09-17 01:27:03           US
# 2  383-85-6348  2020-10-01 01:30:20           US

# %%
pdf[-3:]
pdf[-2:]
# Out:
#     first_name last_name                  email gender suffix      title  \
# 998     Sharla    Beggin  sbegginrq@shop-pro.jp      F    NaN  Honorable
# 999      Luigi     Golby  lgolbyrr@freewebs.com      M    NaN        NaN
#
#                 address            department  \
# 998  8557 Pleasure Park  Business Development
# 999    64 Larry Parkway             Marketing
#
#                         bitcoin_address           company          ssn  \
# 998  13riqoS73GSScYNiP76DZQjoJ3JgaWu26M     Torp-Schiller  232-45-2522
# 999  18UZKGyrA2JxSgjCghfyJgmm2AkzhD5iYZ  Nitzsche-Dickens  841-13-1501
#
#           employee_start country_code
# 998  2021-02-08 19:12:31           US
# 999  2020-01-08 21:16:56           PH

# %%
pdf['new_column'] = pdf['gender'] + ' ' + pdf['last_name']
pdf['new_column2'] = pdf['gender'] + ' ' + pdf['department']
pdf.head()
# Out:
#   first_name   last_name                        email gender suffix  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
# 3   Marrilee       Burtt              mburtt3@nps.gov      F     Sr
# 4        Ava    Burchett        aburchett4@taobao.com      F    NaN
#
#        title                     address                department  \
# 0         Dr              98557 2nd Pass                  Services
# 1        Rev                7 Marcy Lane                Accounting
# 2  Honorable       57666 Stoughton Court           Human Resources
# 3        NaN             074 Elgar Point  Research and Development
# 4  Honorable  76045 Mockingbird Crossing                  Services
#
#                       bitcoin_address                        company  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp     Lehner, Willms and McClure
# ...

# %%
pdf.drop('new_column', axis = 1).head() #temporary drop
pdf.drop('address', axis = 1).head()
# Out:
#   first_name   last_name                        email gender suffix  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
# 3   Marrilee       Burtt              mburtt3@nps.gov      F     Sr
# 4        Ava    Burchett        aburchett4@taobao.com      F    NaN
#
#        title                department                     bitcoin_address  \
# 0         Dr                  Services  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp
# 1        Rev                Accounting  18c1EisbFW7PrRyXoZcztY2oRUuUcnJ2hK
# 2  Honorable           Human Resources  1DuQgLuydME3HtXrYtDm6xk8agNqozhzs9
# 3        NaN  Research and Development  12jmLByL7ngA6TLpRPNAtuh7Src7LGhiKn
# 4  Honorable                  Services  1FDyhoQmmcrHXCcWD4cMy7VJCankW1K9R3
#
#                          company          ssn       employee_start  \
# ...

# %%
pdf.head()
pdf = pdf.drop('new_column', axis = 1) #permanent drop

# %%
pdf.head()
# Out:
#   first_name   last_name                        email gender suffix  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
# 3   Marrilee       Burtt              mburtt3@nps.gov      F     Sr
# 4        Ava    Burchett        aburchett4@taobao.com      F    NaN
#
#        title                     address                department  \
# 0         Dr              98557 2nd Pass                  Services
# 1        Rev                7 Marcy Lane                Accounting
# 2  Honorable       57666 Stoughton Court           Human Resources
# 3        NaN             074 Elgar Point  Research and Development
# 4  Honorable  76045 Mockingbird Crossing                  Services
#
#                       bitcoin_address                        company  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp     Lehner, Willms and McClure
# ...

# %%
selectpdf = pdf[['first_name', 'last_name', 'department']]  #making a new dataframe by selecting columns from old one
selectpdf.head()
# Out:
#   first_name   last_name                department
# 0      Weber  Massenhove                  Services
# 1    Grethel       Boyce                Accounting
# 2     Wilmar     Duester           Human Resources
# 3   Marrilee       Burtt  Research and Development
# 4        Ava    Burchett                  Services

# %%
selectpdf.drop('department', axis = 1, inplace=True) #inplace lets you drop without the need to make dataframe equal to itself
selectpdf.head()
# Out:
#   first_name   last_name
# 0      Weber  Massenhove
# 1    Grethel       Boyce
# 2     Wilmar     Duester
# 3   Marrilee       Burtt
# 4        Ava    Burchett

# %%
#pd.read_csv??

# %%
pdf.head(4) #4 rows selected to be viewed
byeindexdf = pd.read_csv('EXAM_DATA_COMPANY.csv', index_col=0) #gets rid of index and makes first row the index
byeindexdf.head()
# Out:
#                                                   company market_cap  \
# address
# 74409 La Follette Hill                    Botsford-Dooley     $3.32B
# 4 Kropf Crossing           Buckridge, Conroy and Nitzsche    $93.98M
# 34952 Badeau Street       Hegmann, Emmerich and O'Connell    $34.63M
# 876 Golf Course Junction          Littel, Rau and Kuhlman        NaN
# 913 Ludington Parkway                   Becker-Macejkovic        NaN
#
#                                                     industry state  \
# address
# 74409 La Follette Hill                Oil Refining/Marketing   NaN
# 4 Kropf Crossing                       Major Pharmaceuticals    NY
# 34952 Badeau Street               Medical/Dental Instruments   NaN
# 876 Golf Course Junction  Department/Specialty Retail Stores   OAX
# 913 Ludington Parkway                                    NaN   NaN
#
#                                 country country_code stock_symbol  \
# address
# ...

# %%
renamedf = byeindexdf.rename(columns = {'company':' business ', 'market_cap': ' profit '}) #changing columns
renamedf.head()
# Out:
#                                                 business   profit   \
# address
# 74409 La Follette Hill                    Botsford-Dooley   $3.32B
# 4 Kropf Crossing           Buckridge, Conroy and Nitzsche  $93.98M
# 34952 Badeau Street       Hegmann, Emmerich and O'Connell  $34.63M
# 876 Golf Course Junction          Littel, Rau and Kuhlman      NaN
# 913 Ludington Parkway                   Becker-Macejkovic      NaN
#
#                                                     industry state  \
# address
# 74409 La Follette Hill                Oil Refining/Marketing   NaN
# 4 Kropf Crossing                       Major Pharmaceuticals    NY
# 34952 Badeau Street               Medical/Dental Instruments   NaN
# 876 Golf Course Junction  Department/Specialty Retail Stores   OAX
# 913 Ludington Parkway                                    NaN   NaN
#
#                                 country country_code stock_symbol  \
# address
# ...

# %%
renamedf.columns #showing the different column titles, helps show if there is random spaces in column titles
# Out:
# Index([' business ', ' profit ', 'industry', 'state', 'country',
#        'country_code', 'stock_symbol', 'time_zone'],
#       dtype='object')

# %%
renamedf = renamedf.rename(mapper=str.strip, axis = 1) #gets rid of white spaces on columns, must make variable equal to itself or you could use inplace equals true
renamedf.columns
# Out:
# Index(['business', 'profit', 'industry', 'state', 'country', 'country_code',
#        'stock_symbol', 'time_zone'],
#       dtype='object')

# %%
cols = list(renamedf.columns) #making list from column names

# %%
uppercols = [x.upper().strip() for x in cols] #list comprehension to turn to upper case
uppercols
# Out:
# ['BUSINESS',
#  'PROFIT',
#  'INDUSTRY',
#  'STATE',
#  'COUNTRY',
#  'COUNTRY_CODE',
#  'STOCK_SYMBOL',
#  'TIME_ZONE']

# %%
renamedf.columns = uppercols #placing uppercase words in the dataframe
renamedf.head(3)
# Out:
#                                                BUSINESS   PROFIT  \
# address
# 74409 La Follette Hill                  Botsford-Dooley   $3.32B
# 4 Kropf Crossing         Buckridge, Conroy and Nitzsche  $93.98M
# 34952 Badeau Street     Hegmann, Emmerich and O'Connell  $34.63M
#
#                                           INDUSTRY STATE        COUNTRY  \
# address
# 74409 La Follette Hill      Oil Refining/Marketing   NaN         Taiwan
# 4 Kropf Crossing             Major Pharmaceuticals    NY  United States
# 34952 Badeau Street     Medical/Dental Instruments   NaN          China
#
#                        COUNTRY_CODE STOCK_SYMBOL         TIME_ZONE
# address
# 74409 La Follette Hill           TW          BCO       Asia/Taipei
# 4 Kropf Crossing                 US         CTIC  America/New_York
# 34952 Badeau Street              CN         MGCD     Asia/Shanghai

# %%
type(pdf) #whether pdf is a dataframe or a series
# Out:
# pandas.core.frame.DataFrame

# %%
len(pdf) #how many rows including column name row
# Out:
# 1000

# %%
pdf.tail(2)
# Out:
#     first_name last_name                  email gender suffix      title  \
# 998     Sharla    Beggin  sbegginrq@shop-pro.jp      F    NaN  Honorable
# 999      Luigi     Golby  lgolbyrr@freewebs.com      M    NaN        NaN
#
#                 address            department  \
# 998  8557 Pleasure Park  Business Development
# 999    64 Larry Parkway             Marketing
#
#                         bitcoin_address           company          ssn  \
# 998  13riqoS73GSScYNiP76DZQjoJ3JgaWu26M     Torp-Schiller  232-45-2522
# 999  18UZKGyrA2JxSgjCghfyJgmm2AkzhD5iYZ  Nitzsche-Dickens  841-13-1501
#
#           employee_start country_code             new_column2
# 998  2021-02-08 19:12:31           US  F Business Development
# 999  2020-01-08 21:16:56           PH             M Marketing

# %%
person_df
pdf.drop('title', axis  =1)

pdf.where(pdf['department'] == 'Services').dropna()  #drop na
pdf.head()
pdf[pdf['department'] == 'Services'].head() #getting services from department
# Out:
#    first_name    last_name                        email gender suffix  \
# 0       Weber   Massenhove       wmassenhove0@about.com      M    NaN
# 4         Ava     Burchett        aburchett4@taobao.com      F    NaN
# 40      Zaria     Valencia        zvalencia14@amazon.de      F    III
# 73      Maggy  Popplestone     mpopplestone21@about.com      F    NaN
# 75    Arlinda     Sabatier  asabatier23@telegraph.co.uk      F     Sr
#
#         title                     address department  \
# 0          Dr              98557 2nd Pass   Services
# 4   Honorable  76045 Mockingbird Crossing   Services
# 40        Rev       47068 Waxwing Parkway   Services
# 73         Ms         26651 Swallow Point   Services
# 75         Ms         9317 Superior Trail   Services
#
#                        bitcoin_address                        company  \
# 0   1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp     Lehner, Willms and McClure
# 4   1FDyhoQmmcrHXCcWD4cMy7VJCankW1K9R3  Kerluke, Langworth and Spinka
# ...

# %%
newpdf = person_df
import re
for row in newpdf['email']:
    pattern = '.+@.+\.com'
    results = re.findall(pattern, row)
    if results:
        #print(results[0])
# Out:
#   File "<ipython-input-303-9d74a2ae30e6>", line 9
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
newpdf.head()
# Out:
#                  department first_name   last_name  \
# 0                  Services      Weber  Massenhove
# 1                Accounting    Grethel       Boyce
# 2           Human Resources     Wilmar     Duester
# 3  Research and Development   Marrilee       Burtt
# 4                  Services        Ava    Burchett
#
#                          email gender suffix      title  \
# 0       wmassenhove0@about.com      M    NaN         Dr
# 1             gboyce1@etsy.com      F     II        Rev
# 2  wduester2@deliciousdays.com      M    NaN  Honorable
# 3              mburtt3@nps.gov      F     Sr        NaN
# 4        aburchett4@taobao.com      F    NaN  Honorable
#
#                       address                     bitcoin_address  \
# 0              98557 2nd Pass  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp
# 1                7 Marcy Lane  18c1EisbFW7PrRyXoZcztY2oRUuUcnJ2hK
# 2       57666 Stoughton Court  1DuQgLuydME3HtXrYtDm6xk8agNqozhzs9
# ...

# %%
newpdf = newpdf.set_index('department') #setting department to head
newpdf.head()
# Out:
#                          first_name   last_name                        email  \
# department
# Services                      Weber  Massenhove       wmassenhove0@about.com
# Accounting                  Grethel       Boyce             gboyce1@etsy.com
# Human Resources              Wilmar     Duester  wduester2@deliciousdays.com
# Research and Development   Marrilee       Burtt              mburtt3@nps.gov
# Services                        Ava    Burchett        aburchett4@taobao.com
#
#                          gender suffix      title                     address  \
# department
# Services                      M    NaN         Dr              98557 2nd Pass
# Accounting                    F     II        Rev                7 Marcy Lane
# Human Resources               M    NaN  Honorable       57666 Stoughton Court
# Research and Development      F     Sr        NaN             074 Elgar Point
# Services                      F    NaN  Honorable  76045 Mockingbird Crossing
#
# ...

# %%
newpdf = newpdf.reset_index() #rest index
newpdf.head()
# Out:
#                  department first_name   last_name  \
# 0                  Services      Weber  Massenhove
# 1                Accounting    Grethel       Boyce
# 2           Human Resources     Wilmar     Duester
# 3  Research and Development   Marrilee       Burtt
# 4                  Services        Ava    Burchett
#
#                          email gender suffix      title  \
# 0       wmassenhove0@about.com      M    NaN         Dr
# 1             gboyce1@etsy.com      F     II        Rev
# 2  wduester2@deliciousdays.com      M    NaN  Honorable
# 3              mburtt3@nps.gov      F     Sr        NaN
# 4        aburchett4@taobao.com      F    NaN  Honorable
#
#                       address                     bitcoin_address  \
# 0              98557 2nd Pass  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp
# 1                7 Marcy Lane  18c1EisbFW7PrRyXoZcztY2oRUuUcnJ2hK
# 2       57666 Stoughton Court  1DuQgLuydME3HtXrYtDm6xk8agNqozhzs9
# ...

# %%
newpdf.head()
# Out:
#                  department first_name   last_name  \
# 0                  Services      Weber  Massenhove
# 1                Accounting    Grethel       Boyce
# 2           Human Resources     Wilmar     Duester
# 3  Research and Development   Marrilee       Burtt
# 4                  Services        Ava    Burchett
#
#                          email gender suffix      title  \
# 0       wmassenhove0@about.com      M    NaN         Dr
# 1             gboyce1@etsy.com      F     II        Rev
# 2  wduester2@deliciousdays.com      M    NaN  Honorable
# 3              mburtt3@nps.gov      F     Sr        NaN
# 4        aburchett4@taobao.com      F    NaN  Honorable
#
#                       address                     bitcoin_address  \
# 0              98557 2nd Pass  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp
# 1                7 Marcy Lane  18c1EisbFW7PrRyXoZcztY2oRUuUcnJ2hK
# 2       57666 Stoughton Court  1DuQgLuydME3HtXrYtDm6xk8agNqozhzs9
# ...

# %%
indexpdf = pdf
indexpdf.head()
# Out:
#   first_name   last_name                        email gender suffix  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
# 3   Marrilee       Burtt              mburtt3@nps.gov      F     Sr
# 4        Ava    Burchett        aburchett4@taobao.com      F    NaN
#
#        title                     address                department  \
# 0         Dr              98557 2nd Pass                  Services
# 1        Rev                7 Marcy Lane                Accounting
# 2  Honorable       57666 Stoughton Court           Human Resources
# 3        NaN             074 Elgar Point  Research and Development
# 4  Honorable  76045 Mockingbird Crossing                  Services
#
#                       bitcoin_address                        company  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp     Lehner, Willms and McClure
# ...

# %%
indexpdf = indexpdf.set_index(['first_name', 'last_name']) #making index first name and last name
indexpdf.head()
# Out:
#                                              email gender suffix      title  \
# first_name last_name
# Weber      Massenhove       wmassenhove0@about.com      M    NaN         Dr
# Grethel    Boyce                  gboyce1@etsy.com      F     II        Rev
# Wilmar     Duester     wduester2@deliciousdays.com      M    NaN  Honorable
# Marrilee   Burtt                   mburtt3@nps.gov      F     Sr        NaN
# Ava        Burchett          aburchett4@taobao.com      F    NaN  Honorable
#
#                                           address                department  \
# first_name last_name
# Weber      Massenhove              98557 2nd Pass                  Services
# Grethel    Boyce                     7 Marcy Lane                Accounting
# Wilmar     Duester          57666 Stoughton Court           Human Resources
# Marrilee   Burtt                  074 Elgar Point  Research and Development
# Ava        Burchett    76045 Mockingbird Crossing                  Services
#
# ...

# %%
indexpdf = indexpdf.reset_index() #resetting index
indexpdf.head()
# Out:
#   first_name   last_name                        email gender suffix  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
# 3   Marrilee       Burtt              mburtt3@nps.gov      F     Sr
# 4        Ava    Burchett        aburchett4@taobao.com      F    NaN
#
#        title                     address                department  \
# 0         Dr              98557 2nd Pass                  Services
# 1        Rev                7 Marcy Lane                Accounting
# 2  Honorable       57666 Stoughton Court           Human Resources
# 3        NaN             074 Elgar Point  Research and Development
# 4  Honorable  76045 Mockingbird Crossing                  Services
#
#                       bitcoin_address                        company  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp     Lehner, Willms and McClure
# ...

# %%
indexpdf[(indexpdf['department'] == 'Services') & (indexpdf['country_code'] == 'ID')] #mask getting those that fit both parameters
# Out:
#     first_name    last_name                       email gender suffix title  \
# 0        Weber   Massenhove      wmassenhove0@about.com      M    NaN    Dr
# 228     Kimble  L'Episcopio       klepiscopio6c@npr.org      M    NaN    Ms
# 399    Eadmund     Champkin  echampkinb3@soundcloud.com      M     II    Dr
# 546      Lance      Carlill  lcarlillf6@liveinternet.ru      M    NaN   Mrs
# 641       Keen  Rotherforth      krotherforthht@loc.gov      M    NaN    Ms
#
#                 address department                     bitcoin_address  \
# 0        98557 2nd Pass   Services  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp
# 228  462 Buell Junction   Services  17iHPXi7rtDw4nBHU6HPUWrve8KuJhHiEJ
# 399   3 Ridge Oak Trail   Services  1HYYnZUHaBVFTv5XH6JZwU4mEz1UASUa4N
# 546  6 Ludington Circle   Services  15LpZyaJyJcMjF47nEVBKTYVpivHYRR2ii
# 641    446 Rowland Road   Services  1KAMfA4ypD9gCwDkF7RDUWwdQPcFsN2V9x
#
#                              company          ssn       employee_start  \
# ...

# %%
indexpdf[(indexpdf['gender'] == 'M') & (indexpdf['department'] == 'Accounting')].head(3)
# Out:
#    first_name last_name                     email gender suffix title  \
# 16     Spense   Parlett       sparlettg@sogou.com      M    NaN   Mrs
# 32     Yancey    Ingman  yingmanw@studiopress.com      M    NaN    Ms
# 39    Winston     Obell      wobell13@godaddy.com      M    NaN   Mrs
#
#                 address  department                     bitcoin_address  \
# 16  97082 Pleasure Pass  Accounting  1CbwEGGHTP4e1cVdfsgiUuaQCjG8xwZ6At
# 32       6097 Utah Park  Accounting  1QJo9K6X8MnoiNkHPXZX5Ux4SpXL33FThc
# 39    5 Macpherson Road  Accounting   1NjFSLndbGMQN5vYrJDJuC41J7xUxMFQ6
#
#                        company          ssn       employee_start country_code  \
# 16                Pouros Group  481-58-4380  2021-02-14 12:15:17           JO
# 32                     Kub Inc  459-79-7753  2021-01-22 10:17:58           US
# 39  DuBuque, Yundt and Spencer  851-91-7592  2020-01-07 21:58:51           CN
#
#      new_column2
# 16  M Accounting
# 32  M Accounting
# 39  M Accounting

# %%
indexpdf = indexpdf.set_index(['company', 'department'])
indexpdf.head()
# Out:
#                                                        first_name   last_name  \
# company                       department
# Lehner, Willms and McClure    Services                      Weber  Massenhove
# Boehm, VonRueden and Turner   Accounting                  Grethel       Boyce
# Harris, Abbott and O'Kon      Human Resources              Wilmar     Duester
# Feeney-Gusikowski             Research and Development   Marrilee       Burtt
# Kerluke, Langworth and Spinka Services                        Ava    Burchett
#
#                                                                               email  \
# company                       department
# Lehner, Willms and McClure    Services                       wmassenhove0@about.com
# Boehm, VonRueden and Turner   Accounting                           gboyce1@etsy.com
# Harris, Abbott and O'Kon      Human Resources           wduester2@deliciousdays.com
# ...

# %%
indexpdf.loc[("Harris, Abbott and O'Kon", 'Human Resources')] #locking on label from index
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
#                                          first_name last_name  \
# company                  department
# Harris, Abbott and O'Kon Human Resources     Wilmar   Duester
#
#                                                                 email gender  \
# company                  department
# Harris, Abbott and O'Kon Human Resources  wduester2@deliciousdays.com      M
#
#                                          suffix      title  \
# company                  department
# Harris, Abbott and O'Kon Human Resources    NaN  Honorable
#
#                                                         address  \
# company                  department
# Harris, Abbott and O'Kon Human Resources  57666 Stoughton Court
#
#                                                              bitcoin_address  \
# ...

# %%
indexpdf.iloc[0] #locking on information from first row
# Out:
# first_name                                      Weber
# last_name                                  Massenhove
# email                          wmassenhove0@about.com
# gender                                              M
# suffix                                            NaN
# title                                              Dr
# address                                98557 2nd Pass
# bitcoin_address    1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp
# ssn                                       527-63-1710
# employee_start                    2021-02-02 03:48:49
# country_code                                       ID
# new_column2                                M Services
# Name: (Lehner, Willms and McClure, Services), dtype: object

# %%
indexpdf.iloc[0]['first_name'] #locing on information from first row and getting firstname
# Out:
# 'Weber'

# %%
qpdf = transact_df
qpdf.head()
# Out:
#                       BITCOIN_ADDRESS    AMOUNT         DATE         TIME  \
# 0  13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A  €8605,56  19-Oct-2020  11:12:56 PM
# 1  1HDSWNybswRtsFFGLFxAQrRzkvssT3NNaR  €2019,11  28-Dec-2020   9:43:06 PM
# 2  12kiq1UUw6aBgnGZBMFZaW7hDbH51uA4A6  €9984,66  26-Nov-2020   5:56:19 PM
# 3  1EXyq8wdLhZcDECocKDGZ7aCq6RmETeYJb  €5709,95  03-Jun-2020   7:38:22 PM
# 4  15mp1C8hQeZ8gU5cqT61YBevptAtsjdWZQ  £5149.41  18-Sep-2020   8:57:58 PM
#
#        TIME_ZONE PURCHASE_APP    CATEGORY  TIME_OFFSET
# 0  Europe/Warsaw         Stim       Music         10.0
# 1  Asia/Shanghai     Treeflex         NaN         -3.0
# 2    Asia/Harbin      Konklab  Industrial          4.0
# 3    Asia/Tehran        Otcom      Beauty         -4.0
# 4    Europe/Kiev      Veribet         NaN          2.0

# %%
qpdf['purchase_app'].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'purchase_app'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-318-0658daed84c6> in <module>
# ----> 1 qpdf['purchase_app'].head()
#
# ...

# %%
qpdf = qpdf.set_index('bitcoin_address')
qpdf.loc['13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-319-4cd3974c88af> in <module>
# ----> 1 qpdf = qpdf.set_index('bitcoin_address')
#       2 qpdf.loc['13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A']
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4389
#    4390         if missing:
# -> 4391             raise KeyError("None of {} are in the columns".format(missing))
#    4392
#    4393         if inplace:
#
# KeyError: "None of ['bitcoin_address'] are in the columns"

# %%
locpdf = pdf
locpdf
locpdf = locpdf.set_index(['first_name', 'last_name'])
#locpdf.head()
#type(locpdf.loc[('Annie', 'Janway')])
locpdf.loc['Annie']
#type(locpdf.loc['Annie'])
# Out:
#                                    email gender suffix      title  \
# last_name
# Musslewhite  amusslewhitebo@bluehost.com      F    NaN  Honorable
# Janway             ajanwayn9@plala.or.jp      F    NaN        NaN
#
#                              address                department  \
# last_name
# Musslewhite  1 Clyde Gallagher Drive                     Sales
# Janway            38 Holy Cross Pass  Research and Development
#
#                                 bitcoin_address                      company  \
# last_name
# Musslewhite  1HMerTzVYZ7Zfg146SEN1yFhGEFoAvYxmm   Schumm, Deckow and Padberg
# Janway       1BeuEzkZsEz7WsRKPiiDJFkMvvpt7CyjNo  Baumbach, Schaden and Robel
#
#                      ssn       employee_start country_code  \
# last_name
# Musslewhite  315-71-7188  2020-02-04 06:08:51           US
# Janway       809-20-9992  2021-02-10 14:39:56           DO
#
#                             new_column2
# last_name
# Musslewhite                     F Sales
# ...

# %%
locpdf.loc[('Annie', 'Janway'), 'department'] #gets department from series
# Out:
# 'Research and Development'

# %%
locpdf.loc[('Annie', 'Janway'), ['department']] #series for annie and department
# Out:
# department    Research and Development
# Name: (Annie, Janway), dtype: object

# %%
locpdf.loc['Annie', 'department'] #series for annie and department
# Out:
# last_name
# Musslewhite                       Sales
# Janway         Research and Development
# Name: department, dtype: object

# %%
locpdf.loc['Annie', ['department']] #creates dateframe for annie and department
# Out:
#                            department
# last_name
# Musslewhite                     Sales
# Janway       Research and Development

# %%
locpdf.loc['Annie', ['department', 'address']] #dataframe with department and address
# Out:
#                            department                  address
# last_name
# Musslewhite                     Sales  1 Clyde Gallagher Drive
# Janway       Research and Development       38 Holy Cross Pass

# %%
ilocdf = company_df
ilocdf.head(3)
# Out:
#                   ADDRESS                          COMPANY MARKET_CAP  \
# 0  74409 La Follette Hill                  Botsford-Dooley     $3.32B
# 1        4 Kropf Crossing   Buckridge, Conroy and Nitzsche    $93.98M
# 2     34952 Badeau Street  Hegmann, Emmerich and O'Connell    $34.63M
#
#                      INDUSTRY STATE        COUNTRY COUNTRY_CODE STOCK_SYMBOL  \
# 0      Oil Refining/Marketing   NaN         Taiwan           TW          BCO
# 1       Major Pharmaceuticals    NY  United States           US         CTIC
# 2  Medical/Dental Instruments   NaN          China           CN         MGCD
#
#           TIME_ZONE
# 0       Asia/Taipei
# 1  America/New_York
# 2     Asia/Shanghai

# %%
ilocdf.iloc[0 , 2] #row 3 column 2 (index style)
# Out:
# '$3.32B'

# %%
ilocdf.iloc[0:2, 1:3] #row 0 and 1 and column 1 and 2
# Out:
#                           COMPANY MARKET_CAP
# 0                 Botsford-Dooley     $3.32B
# 1  Buckridge, Conroy and Nitzsche    $93.98M

# %%
indexdf = company_df
indexdf.columns
# Out:
# Index(['ADDRESS', 'COMPANY', 'MARKET_CAP', 'INDUSTRY', 'STATE', 'COUNTRY',
#        'COUNTRY_CODE', 'STOCK_SYMBOL', 'TIME_ZONE'],
#       dtype='object')

# %%
indexdf.columns = [x.upper().strip() for x in indexdf.columns] #way easier to just make list comprehension equal to indexdf.columns
indexdf.head()
# Out:
#                     ADDRESS                          COMPANY MARKET_CAP  \
# 0    74409 La Follette Hill                  Botsford-Dooley     $3.32B
# 1          4 Kropf Crossing   Buckridge, Conroy and Nitzsche    $93.98M
# 2       34952 Badeau Street  Hegmann, Emmerich and O'Connell    $34.63M
# 3  876 Golf Course Junction          Littel, Rau and Kuhlman        NaN
# 4     913 Ludington Parkway                Becker-Macejkovic        NaN
#
#                              INDUSTRY STATE        COUNTRY COUNTRY_CODE  \
# 0              Oil Refining/Marketing   NaN         Taiwan           TW
# 1               Major Pharmaceuticals    NY  United States           US
# 2          Medical/Dental Instruments   NaN          China           CN
# 3  Department/Specialty Retail Stores   OAX         Mexico           MX
# 4                                 NaN   NaN          China           CN
#
#   STOCK_SYMBOL            TIME_ZONE
# 0          BCO          Asia/Taipei
# ...

# %%
indexmask = indexdf[indexdf['INDUSTRY'] == 'Medical/Dental Instruments']
indexmask.head()
# Out:
#                  ADDRESS                          COMPANY MARKET_CAP  \
# 2    34952 Badeau Street  Hegmann, Emmerich and O'Connell    $34.63M
# 64         50 Grim Court                        Crist Inc     $3.34B
# 106    955 Coleman Trail       Cartwright, Ledner and Von     $8.33M
#
#                        INDUSTRY STATE      COUNTRY COUNTRY_CODE STOCK_SYMBOL  \
# 2    Medical/Dental Instruments   NaN        China           CN         MGCD
# 64   Medical/Dental Instruments    16  Netherlands           NL         ICUI
# 106  Medical/Dental Instruments   MOR       Mexico           MX         DCTH
#
#                TIME_ZONE
# 2          Asia/Shanghai
# 64      Europe/Amsterdam
# 106  America/Mexico_City

# %%
transact_df.dtypes
#indextransact = transact_df[transact_df['']]
# Out:
# BITCOIN_ADDRESS     object
# AMOUNT              object
# DATE                object
# TIME                object
# TIME_ZONE           object
# PURCHASE_APP        object
# CATEGORY            object
# TIME_OFFSET        float64
# dtype: object

# %%
indextransact = transact_df[transact_df['time_offset'] > 5] #getting times greater than 5
indextransact.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time_offset'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-333-249335a047cc> in <module>
# ...

# %%
indextransact2 = transact_df.where(transact_df['time_offset'] > 5).dropna() #where is like a mask but instead of only returning what is in the mask, turns everything not in the mask to na after which you drop na
indextransact2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time_offset'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-334-acd9877938ec> in <module>
# ...

# %%
indextransact3 = transact_df[(transact_df['time_offset'] > 5) & (transact_df['time_offset'] < 7)] #make sure to use paranthesis
indextransact3.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time_offset'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-335-5645e8c85969> in <module>
# ...

# %%
transposedf = transact_df
transposedf.T #turns columns to rows and rows to columns
# Out:
#                                                 0    \
# BITCOIN_ADDRESS  13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A
# AMOUNT                                     €8605,56
# DATE                                    19-Oct-2020
# TIME                                    11:12:56 PM
# TIME_ZONE                             Europe/Warsaw
# PURCHASE_APP                                   Stim
# CATEGORY                                      Music
# TIME_OFFSET                                      10
#
#                                                 1    \
# BITCOIN_ADDRESS  1HDSWNybswRtsFFGLFxAQrRzkvssT3NNaR
# AMOUNT                                     €2019,11
# DATE                                    28-Dec-2020
# TIME                                     9:43:06 PM
# TIME_ZONE                             Asia/Shanghai
# PURCHASE_APP                               Treeflex
# CATEGORY                                        NaN
# TIME_OFFSET                                      -3
#
# ...

# %%
multidf = person_df
multidf['department'].unique() #looking at unique names in department
# Out:
# array(['Services', 'Accounting', 'Human Resources',
#        'Research and Development', 'Legal', 'Support', 'Training',
#        'Sales', 'Engineering', 'Business Development',
#        'Product Management', 'Marketing'], dtype=object)

# %%
multidf[multidf['department'] == 'Sales'].head(2) #grabbing information when department is sales
# Out:
#    first_name last_name                email gender suffix title  \
# 11     Alonso   Fitchen    afitchenb@nba.com      M    NaN   NaN
# 46      Hermy     Manus  hmanus1a@tumblr.com      M    NaN    Dr
#
#                 address department                     bitcoin_address  \
# 11  05 Mandrake Parkway      Sales  1C68HJM7YwumejWCsjeoADN973qxHNUEWH
# 46      8 Maryland Pass      Sales  1JgRb8Lex1wnQ3eXZc8LE18XnvNu2LSyLj
#
#                         company          ssn       employee_start  \
# 11  Abernathy, Emard and Senger  253-43-8746  2020-05-28 14:34:45
# 46                    Upton Inc  785-08-0371  2020-09-01 12:38:47
#
#    country_code new_column2
# 11           PT     M Sales
# 46           US     M Sales

# %%
person_df = person_df.drop('new_column', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-339-91dc48502514> in <module>
# ----> 1 person_df = person_df.drop('new_column', axis = 1)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4095             level=level,
#    4096             inplace=inplace,
# -> 4097             errors=errors,
#    4098         )
#    4099
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3913         for axis, labels in axes.items():
#    3914             if labels is not None:
# -> 3915                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3916
#    3917         if inplace:
#
# ...

# %%
multidf2 = person_df.set_index(['department', 'company'])
multidf2.loc[('Sales', 'Upton Inc')] #indexing both department and company
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#                      first_name last_name                email gender suffix  \
# department company
# Sales      Upton Inc      Hermy     Manus  hmanus1a@tumblr.com      M    NaN
#
#                      title          address  \
# department company
# Sales      Upton Inc    Dr  8 Maryland Pass
#
#                                          bitcoin_address          ssn  \
# department company
# Sales      Upton Inc  1JgRb8Lex1wnQ3eXZc8LE18XnvNu2LSyLj  785-08-0371
#
#                            employee_start country_code new_column2
# department company
# Sales      Upton Inc  2020-09-01 12:38:47           US     M Sales

# %%
multidf2.loc[('Sales', 'Upton Inc')]['email'] #getting email
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
# department  company
# Sales       Upton Inc    hmanus1a@tumblr.com
# Name: email, dtype: object

# %%
transact_df.columns
# Out:
# Index(['BITCOIN_ADDRESS', 'AMOUNT', 'DATE', 'TIME', 'TIME_ZONE',
#        'PURCHASE_APP', 'CATEGORY', 'TIME_OFFSET'],
#       dtype='object')

# %%
multitrans = transact_df
multitrans
#multitrans = multitrans.set_index('purchase_app')
multitrans.loc['Stim'].sort_values('time_offset', ascending = False) #index label Stim sorting values by time_offset, ascending False making largest to smallest
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Stim'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-343-79e98690ed5c> in <module>
#       2 multitrans
#       3 #multitrans = multitrans.set_index('purchase_app')
# ...

# %%
replacetrans = transact_df
replacetrans.dtypes

def replacer(x):   
    if type(x) == str: #checks to see if x is string
        return x.replace('/', '-') 
    return x
replacetrans[replacetrans['time_zone'].apply(replacer)] #grabbing series from replacetrans
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time_zone'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-344-96035393427d> in <module>
# ...

# %%
regpdf = person_df       #not right come back to


def find_ssn(row):
    import re
    pattern = 'd{3}-/d{2}-(/d{4})'
    results = re.findall(pattern, row['ssn'])
    if results:
        return pattern[0]



regpdf['last_four'] = regpdf.apply(find_ssn, axis = 1)
regpdf.head()
# Out:
#   first_name   last_name                        email gender suffix  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
# 3   Marrilee       Burtt              mburtt3@nps.gov      F     Sr
# 4        Ava    Burchett        aburchett4@taobao.com      F    NaN
#
#        title                     address                department  \
# 0         Dr              98557 2nd Pass                  Services
# 1        Rev                7 Marcy Lane                Accounting
# 2  Honorable       57666 Stoughton Court           Human Resources
# 3        NaN             074 Elgar Point  Research and Development
# 4  Honorable  76045 Mockingbird Crossing                  Services
#
#                       bitcoin_address                        company  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp     Lehner, Willms and McClure
# ...

# %%
xyz2 = person_df

xyz2.columns = [x.upper().strip() for x in xyz2.columns]
xyz2
xyz2 = xyz2.rename(columns = {'FIRST_NAME': 'first_name', 'LAST_NAME': 'last_name'})
xyz2.head()
# Out:
#   first_name   last_name                        EMAIL GENDER SUFFIX  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
# 3   Marrilee       Burtt              mburtt3@nps.gov      F     Sr
# 4        Ava    Burchett        aburchett4@taobao.com      F    NaN
#
#        TITLE                     ADDRESS                DEPARTMENT  \
# 0         Dr              98557 2nd Pass                  Services
# 1        Rev                7 Marcy Lane                Accounting
# 2  Honorable       57666 Stoughton Court           Human Resources
# 3        NaN             074 Elgar Point  Research and Development
# 4  Honorable  76045 Mockingbird Crossing                  Services
#
#                       BITCOIN_ADDRESS                        COMPANY  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp     Lehner, Willms and McClure
# ...

# %%
applytransact  = transact_df.reset_index()
applytransact.head()
applytransact = applytransact.drop('index', axis = 1)
applytransact.head()
# Out:
#                       BITCOIN_ADDRESS    AMOUNT         DATE         TIME  \
# 0  13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A  €8605,56  19-Oct-2020  11:12:56 PM
# 1  1HDSWNybswRtsFFGLFxAQrRzkvssT3NNaR  €2019,11  28-Dec-2020   9:43:06 PM
# 2  12kiq1UUw6aBgnGZBMFZaW7hDbH51uA4A6  €9984,66  26-Nov-2020   5:56:19 PM
# 3  1EXyq8wdLhZcDECocKDGZ7aCq6RmETeYJb  €5709,95  03-Jun-2020   7:38:22 PM
# 4  15mp1C8hQeZ8gU5cqT61YBevptAtsjdWZQ  £5149.41  18-Sep-2020   8:57:58 PM
#
#        TIME_ZONE PURCHASE_APP    CATEGORY  TIME_OFFSET
# 0  Europe/Warsaw         Stim       Music         10.0
# 1  Asia/Shanghai     Treeflex         NaN         -3.0
# 2    Asia/Harbin      Konklab  Industrial          4.0
# 3    Asia/Tehran        Otcom      Beauty         -4.0
# 4    Europe/Kiev      Veribet         NaN          2.0

# %%
applytransact['time_offset'].apply(np.average)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time_offset'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-348-12dc32066d23> in <module>
# ...

# %%
applytransact['time_offset'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time_offset'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-349-cdbffe4800f1> in <module>
# ...

# %%
applytransact.dtypes
# Out:
# BITCOIN_ADDRESS     object
# AMOUNT              object
# DATE                object
# TIME                object
# TIME_ZONE           object
# PURCHASE_APP        object
# CATEGORY            object
# TIME_OFFSET        float64
# dtype: object

# %%
def reverser(date):
    return -date

applytransact['time_offset_reverse'] = applytransact['time_offset'].apply(reverser) #apply best for creating new column
applytransact['zeroer'] = applytransact['time_offset'] + applytransact['time_offset_reverse']
applytransact.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time_offset'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-351-2f6179bbc9f5> in <module>
#       2     return -date
#       3
# ...

# %%
applytransact.iloc[[87]]
# Out:
#                        BITCOIN_ADDRESS    AMOUNT         DATE         TIME  \
# 87  15zNYn8qP2cSR5A7hbm7ai8Wbm5ehMTWTX  €2995,36  10-Dec-2020  10:22:30 AM
#
#               TIME_ZONE PURCHASE_APP CATEGORY  TIME_OFFSET
# 87  Atlantic/Cape_Verde       Sonair   Movies        -10.0

# %%
for group, frame in applytransact.groupby('purchase_app'):
    #print(group, '\n\n') #the unique apps
    #print(frame, '\n\n') #information contained with them
    pass
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-353-fae60b4b96f7> in <module>
# ----> 1 for group, frame in applytransact.groupby('purchase_app'):
#       2     #print(group, '\n\n') #the unique apps
#       3     #print(frame, '\n\n') #information contained with them
#       4     pass
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7894             squeeze=squeeze,
#    7895             observed=observed,
# -> 7896             **kwargs
#    7897         )
#    7898
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2476         raise TypeError("invalid type: {}".format(obj))
#    2477
# -> 2478     return klass(obj, by, **kwds)
#
# ...

# %%
def get_first(group_df):
    return group_df.iloc[0]
applytransact.groupby('time_zone').apply(get_first).head() #groupby makes purchase_app the indexs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-354-92b311965596> in <module>
#       1 def get_first(group_df):
#       2     return group_df.iloc[0]
# ----> 3 applytransact.groupby('time_zone').apply(get_first).head() #groupby makes purchase_app the indexs
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7894             squeeze=squeeze,
#    7895             observed=observed,
# -> 7896             **kwargs
#    7897         )
#    7898
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2476         raise TypeError("invalid type: {}".format(obj))
#    2477
# -> 2478     return klass(obj, by, **kwds)
#
# ...

# %%
applytransact = applytransact.reset_index()

# %%
applytransact = applytransact.drop(['level_0', 'index'], axis = 1)
applytransact.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-356-e67d0dbb4635> in <module>
# ----> 1 applytransact = applytransact.drop(['level_0', 'index'], axis = 1)
#       2 applytransact.head()
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4095             level=level,
#    4096             inplace=inplace,
# -> 4097             errors=errors,
#    4098         )
#    4099
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3913         for axis, labels in axes.items():
#    3914             if labels is not None:
# -> 3915                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3916
#    3917         if inplace:
#
# ...

# %%
applytransact.groupby('purchase_app').agg(len).head() #amount of times is placed in each column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-357-4b3438820e0d> in <module>
# ----> 1 applytransact.groupby('purchase_app').agg(len).head() #amount of times is placed in each column
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7894             squeeze=squeeze,
#    7895             observed=observed,
# -> 7896             **kwargs
#    7897         )
#    7898
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2476         raise TypeError("invalid type: {}".format(obj))
#    2477
# -> 2478     return klass(obj, by, **kwds)
#
# ...

# %%
applytransact.head()

applytransact['xyz'] = applytransact.groupby('purchase_app')['time_offset'].transform(len)
applytransact.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-358-1fb85c6bf09b> in <module>
#       1 applytransact.head()
#       2
# ----> 3 applytransact['xyz'] = applytransact.groupby('purchase_app')['time_offset'].transform(len)
#       4 applytransact.head()
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7894             squeeze=squeeze,
#    7895             observed=observed,
# -> 7896             **kwargs
#    7897         )
#    7898
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2476         raise TypeError("invalid type: {}".format(obj))
#    2477
# -> 2478     return klass(obj, by, **kwds)
#
# ...

# %%
applytransact.head()
# Out:
#    index                     BITCOIN_ADDRESS    AMOUNT         DATE  \
# 0      0  13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A  €8605,56  19-Oct-2020
# 1      1  1HDSWNybswRtsFFGLFxAQrRzkvssT3NNaR  €2019,11  28-Dec-2020
# 2      2  12kiq1UUw6aBgnGZBMFZaW7hDbH51uA4A6  €9984,66  26-Nov-2020
# 3      3  1EXyq8wdLhZcDECocKDGZ7aCq6RmETeYJb  €5709,95  03-Jun-2020
# 4      4  15mp1C8hQeZ8gU5cqT61YBevptAtsjdWZQ  £5149.41  18-Sep-2020
#
#           TIME      TIME_ZONE PURCHASE_APP    CATEGORY  TIME_OFFSET
# 0  11:12:56 PM  Europe/Warsaw         Stim       Music         10.0
# 1   9:43:06 PM  Asia/Shanghai     Treeflex         NaN         -3.0
# 2   5:56:19 PM    Asia/Harbin      Konklab  Industrial          4.0
# 3   7:38:22 PM    Asia/Tehran        Otcom      Beauty         -4.0
# 4   8:57:58 PM    Europe/Kiev      Veribet         NaN          2.0

# %%
for x in applytransact['category'].unique(): #going through each category
    avg = np.average(applytransact.where(applytransact['time_zone'] == 'Asia/Tehran').dropna()['time_offset']) #apply the avgerage to time
    print(x, avg)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'category'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-360-16ffbc3dc7dd> in <module>
# ...

# %%
for group, frame in applytransact.groupby('purchase_app'):
    avg = np.average(frame['time_offset'])
    print(group, avg)
    #print(group, '\n\n')
    #print(frame, '\n\n')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-361-53e95ec4a81f> in <module>
# ----> 1 for group, frame in applytransact.groupby('purchase_app'):
#       2     avg = np.average(frame['time_offset'])
#       3     print(group, avg)
#       4     #print(group, '\n\n')
#       5     #print(frame, '\n\n')
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7894             squeeze=squeeze,
#    7895             observed=observed,
# -> 7896             **kwargs
#    7897         )
#    7898
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2476         raise TypeError("invalid type: {}".format(obj))
#    2477
# -> 2478     return klass(obj, by, **kwds)
#
# ...

# %%
compdf = company_df
compdf.head()
compdf = compdf.set_index('COMPANY')
compdf.head()

def botsford(name):
    if 'Botsford' in name:
        return 'Botsford-Dooley'
    else:
        return 'Another Company'
    
for group, frame in compdf.groupby(botsford):
    print(group, '\n\n')
    print(frame, '\n\n')
# Out:
# Another Company
#
#
#                                                    ADDRESS MARKET_CAP  \
# COMPANY
# Buckridge, Conroy and Nitzsche            4 Kropf Crossing    $93.98M
# Hegmann, Emmerich and O'Connell        34952 Badeau Street    $34.63M
# Littel, Rau and Kuhlman           876 Golf Course Junction        NaN
# Becker-Macejkovic                    913 Ludington Parkway        NaN
# Champlin, Steuber and Lehner            0259 Derek Parkway   $607.04M
# ...                                                    ...        ...
# Breitenberg, Stanton and Treutel        7 Northridge Point        NaN
# Bruen LLC                                  434 Gerald Pass   $144.39M
# Donnelly and Sons                      65391 Westport Park     $2.65B
# Pfannerstill LLC                    85992 Westerfield Lane   $685.51M
# Tromp, Zieme and Hackett           0132 Briar Crest Avenue   $487.29M
#
#                                                             INDUSTRY STATE  \
# COMPANY
# ...

# %%
compdf.head()
for group, frame in compdf.groupby(['COUNTRY', 'COUNTRY_CODE']):
    print(group, len(frame))
# Out:
# ('Afghanistan', 'AF') 1
# ('Andorra', 'AD') 1
# ('Argentina', 'AR') 3
# ('Australia', 'AU') 1
# ('Azerbaijan', 'AZ') 1
# ('Bangladesh', 'BD') 1
# ('Bolivia', 'BO') 1
# ('Bosnia and Herzegovina', 'BA') 1
# ('Brazil', 'BR') 8
# ('Burkina Faso', 'BF') 1
# ('Cambodia', 'KH') 1
# ('Canada', 'CA') 1
# ('China', 'CN') 33
# ('Colombia', 'CO') 3
# ('Croatia', 'HR') 2
# ('Czech Republic', 'CZ') 2
# ('Dominican Republic', 'DO') 1
# ('Ecuador', 'EC') 2
# ('Estonia', 'EE') 1
# ('France', 'FR') 5
# ('Gambia', 'GM') 1
# ('Greece', 'GR') 1
# ('Guatemala', 'GT') 1
# ('Honduras', 'HN') 1
# ('Hungary', 'HU') 1
# ('Indonesia', 'ID') 20
# ('Ireland', 'IE') 1
# ('Japan', 'JP') 2
# ('Jordan', 'JO') 1
# ('Kazakhstan', 'KZ') 1
# ('Latvia', 'LV') 1
# ('Lesotho', 'LS') 1
# ('Mexico', 'MX') 2
# ('Mongolia', 'MN') 1
# ('Montenegro', 'ME') 1
# ('Morocco', 'MA') 1
# ('Netherlands', 'NL') 3
# ('Nigeria', 'NG') 3
# ('North Korea', 'KP') 1
# ('Norway', 'NO') 1
# ('Pakistan', 'PK') 2
# ('Peru', 'PE') 1
# ...

# %%
compdf.head()
agger = compdf.groupby('TIME_ZONE').agg({'STOCK_SYMBOL': len}).sort_values(by='STOCK_SYMBOL', ascending = False)

# %%
agger['STOCK_SYMBOL'].agg(np.mean)
# Out:
# 2.4096385542168677

# %%
compdf.groupby('STATE').agg(len).head()
# Out:
#        ADDRESS  MARKET_CAP  INDUSTRY  COUNTRY  COUNTRY_CODE  STOCK_SYMBOL  \
# STATE
# 10           1           1         1        1             1             1
# 11           1           1         1        1             1             1
# 12           1           1         1        1             1             1
# 13           2           2         2        2             2             2
# 14           1           1         1        1             1             1
#
#        TIME_ZONE
# STATE
# 10             1
# 11             1
# 12             1
# 13             2
# 14             1

# %%
display(person_df.head(3))
display(company_df.head(3))


transact_df.columns = [x.strip().upper() for x in transact_df.columns]
display(transact_df.head(3))
# Out:
#   FIRST_NAME   LAST_NAME                        EMAIL GENDER SUFFIX  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
#
#        TITLE                ADDRESS       DEPARTMENT  \
# 0         Dr         98557 2nd Pass         Services
# 1        Rev           7 Marcy Lane       Accounting
# 2  Honorable  57666 Stoughton Court  Human Resources
#
#                       BITCOIN_ADDRESS                      COMPANY  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp   Lehner, Willms and McClure
# 1  18c1EisbFW7PrRyXoZcztY2oRUuUcnJ2hK  Boehm, VonRueden and Turner
# 2  1DuQgLuydME3HtXrYtDm6xk8agNqozhzs9     Harris, Abbott and O'Kon
#
#            SSN       EMPLOYEE_START COUNTRY_CODE        NEW_COLUMN2 LAST_FOUR
# 0  527-63-1710  2021-02-02 03:48:49           ID         M Services      None
# ...

# %%
merger = pd.merge(person_df, company_df, how='left', on='COMPANY')
merger.head(3)
# Out:
#   FIRST_NAME   LAST_NAME                        EMAIL GENDER SUFFIX  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
#
#        TITLE              ADDRESS_x       DEPARTMENT  \
# 0         Dr         98557 2nd Pass         Services
# 1        Rev           7 Marcy Lane       Accounting
# 2  Honorable  57666 Stoughton Court  Human Resources
#
#                       BITCOIN_ADDRESS                      COMPANY  ...  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp   Lehner, Willms and McClure  ...
# 1  18c1EisbFW7PrRyXoZcztY2oRUuUcnJ2hK  Boehm, VonRueden and Turner  ...
# 2  1DuQgLuydME3HtXrYtDm6xk8agNqozhzs9     Harris, Abbott and O'Kon  ...
#
#          NEW_COLUMN2 LAST_FOUR           ADDRESS_y MARKET_CAP  \
# 0         M Services      None  442 Heath Junction     $5.25B
# ...

# %%
merger2 = pd.merge(person_df, company_df, how='inner', on=['COMPANY', 'ADDRESS'])
merger.head(3)
# Out:
#   FIRST_NAME   LAST_NAME                        EMAIL GENDER SUFFIX  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
#
#        TITLE              ADDRESS_x       DEPARTMENT  \
# 0         Dr         98557 2nd Pass         Services
# 1        Rev           7 Marcy Lane       Accounting
# 2  Honorable  57666 Stoughton Court  Human Resources
#
#                       BITCOIN_ADDRESS                      COMPANY  ...  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp   Lehner, Willms and McClure  ...
# 1  18c1EisbFW7PrRyXoZcztY2oRUuUcnJ2hK  Boehm, VonRueden and Turner  ...
# 2  1DuQgLuydME3HtXrYtDm6xk8agNqozhzs9     Harris, Abbott and O'Kon  ...
#
#          NEW_COLUMN2 LAST_FOUR           ADDRESS_y MARKET_CAP  \
# 0         M Services      None  442 Heath Junction     $5.25B
# ...

# %%
merger3 = pd.merge(company_df, transact_df, on = 'TIME_ZONE', how = 'inner')
merger3.head(3)
# Out:
#             ADDRESS                         COMPANY MARKET_CAP  \
# 0  4 Kropf Crossing  Buckridge, Conroy and Nitzsche    $93.98M
# 1  4 Kropf Crossing  Buckridge, Conroy and Nitzsche    $93.98M
# 2  4 Kropf Crossing  Buckridge, Conroy and Nitzsche    $93.98M
#
#                 INDUSTRY STATE        COUNTRY COUNTRY_CODE STOCK_SYMBOL  \
# 0  Major Pharmaceuticals    NY  United States           US         CTIC
# 1  Major Pharmaceuticals    NY  United States           US         CTIC
# 2  Major Pharmaceuticals    NY  United States           US         CTIC
#
#           TIME_ZONE                     BITCOIN_ADDRESS    AMOUNT  \
# 0  America/New_York  1KGBbMgpZqi6mvMh42k7evTXRRxJQp8tzc   $421.60
# 1  America/New_York  1CzbeXKiKSbUJjeEYY9WbgjLBTMQ65rEwJ  £2874.56
# 2  America/New_York  13DYwpNkiUZAJZceZwzhsdJqr3mXbrNKo9  ¥2079.17
#
#           DATE         TIME PURCHASE_APP    CATEGORY  TIME_OFFSET
# 0  24-Feb-2021   8:32:47 AM      Bitchip         NaN         -1.0
# ...

# %%
merger4 = pd.merge(person_df, transact_df, on = ['BITCOIN_ADDRESS'], how = 'left')
merger4.head(3)
# Out:
#   FIRST_NAME   LAST_NAME                        EMAIL GENDER SUFFIX  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
#
#        TITLE                ADDRESS       DEPARTMENT  \
# 0         Dr         98557 2nd Pass         Services
# 1        Rev           7 Marcy Lane       Accounting
# 2  Honorable  57666 Stoughton Court  Human Resources
#
#                       BITCOIN_ADDRESS                      COMPANY  ...  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp   Lehner, Willms and McClure  ...
# 1  18c1EisbFW7PrRyXoZcztY2oRUuUcnJ2hK  Boehm, VonRueden and Turner  ...
# 2  1DuQgLuydME3HtXrYtDm6xk8agNqozhzs9     Harris, Abbott and O'Kon  ...
#
#   COUNTRY_CODE        NEW_COLUMN2 LAST_FOUR    AMOUNT         DATE  \
# 0           ID         M Services      None       NaN          NaN
# ...

# %%
altindexperson = person_df.set_index('FIRST_NAME')


merger5 = pd.merge(altindexperson, company_df, how='inner', on=['COMPANY', 'ADDRESS'], left_index = True, right_index = True)
merger5.head(3)
# Out:
# Empty DataFrame
# Columns: [LAST_NAME, EMAIL, GENDER, SUFFIX, TITLE, ADDRESS, DEPARTMENT, BITCOIN_ADDRESS, COMPANY, SSN, EMPLOYEE_START, COUNTRY_CODE_x, NEW_COLUMN2, LAST_FOUR, MARKET_CAP, INDUSTRY, STATE, COUNTRY, COUNTRY_CODE_y, STOCK_SYMBOL, TIME_ZONE]
# Index: []
#
# [0 rows x 21 columns]

# %%
display(person_df.head(3))
display(company_df.head(3))


transact_df.columns = [x.strip().upper() for x in transact_df.columns]
display(transact_df.head(3))
# Out:
#   FIRST_NAME   LAST_NAME                        EMAIL GENDER SUFFIX  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
#
#        TITLE                ADDRESS       DEPARTMENT  \
# 0         Dr         98557 2nd Pass         Services
# 1        Rev           7 Marcy Lane       Accounting
# 2  Honorable  57666 Stoughton Court  Human Resources
#
#                       BITCOIN_ADDRESS                      COMPANY  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp   Lehner, Willms and McClure
# 1  18c1EisbFW7PrRyXoZcztY2oRUuUcnJ2hK  Boehm, VonRueden and Turner
# 2  1DuQgLuydME3HtXrYtDm6xk8agNqozhzs9     Harris, Abbott and O'Kon
#
#            SSN       EMPLOYEE_START COUNTRY_CODE        NEW_COLUMN2 LAST_FOUR
# 0  527-63-1710  2021-02-02 03:48:49           ID         M Services      None
# ...

# %%
xmerg = pd.merge(person_df, company_df, how='left', on=['COMPANY', 'COUNTRY_CODE', 'ADDRESS'])
#xmerg = pd.merge(person_df, company_df, how='left', on=['COMPANY', 'COUNTRY_CODE'])
xmerg.head()
# Out:
#   FIRST_NAME   LAST_NAME                        EMAIL GENDER SUFFIX  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
# 3   Marrilee       Burtt              mburtt3@nps.gov      F     Sr
# 4        Ava    Burchett        aburchett4@taobao.com      F    NaN
#
#        TITLE                     ADDRESS                DEPARTMENT  \
# 0         Dr              98557 2nd Pass                  Services
# 1        Rev                7 Marcy Lane                Accounting
# 2  Honorable       57666 Stoughton Court           Human Resources
# 3        NaN             074 Elgar Point  Research and Development
# 4  Honorable  76045 Mockingbird Crossing                  Services
#
#                       BITCOIN_ADDRESS                        COMPANY  ...  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp     Lehner, Willms and McClure  ...
# ...

# %%
xmerge2 = pd.merge(person_df, company_df, how= 'outer')
xmerge2.head(5)
# Out:
#   FIRST_NAME   LAST_NAME                        EMAIL GENDER SUFFIX  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
# 3   Marrilee       Burtt              mburtt3@nps.gov      F     Sr
# 4        Ava    Burchett        aburchett4@taobao.com      F    NaN
#
#        TITLE                     ADDRESS                DEPARTMENT  \
# 0         Dr              98557 2nd Pass                  Services
# 1        Rev                7 Marcy Lane                Accounting
# 2  Honorable       57666 Stoughton Court           Human Resources
# 3        NaN             074 Elgar Point  Research and Development
# 4  Honorable  76045 Mockingbird Crossing                  Services
#
#                       BITCOIN_ADDRESS                        COMPANY  ...  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp     Lehner, Willms and McClure  ...
# ...

# %%
d = pd.concat([person_df, company_df])
d.head(1)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#           ADDRESS                     BITCOIN_ADDRESS  \
# 0  98557 2nd Pass  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp
#
#                       COMPANY COUNTRY COUNTRY_CODE DEPARTMENT  \
# 0  Lehner, Willms and McClure     NaN           ID   Services
#
#                     EMAIL       EMPLOYEE_START FIRST_NAME GENDER  ...  \
# 0  wmassenhove0@about.com  2021-02-02 03:48:49      Weber      M  ...
#
#   LAST_FOUR   LAST_NAME MARKET_CAP NEW_COLUMN2          SSN STATE  \
# 0      None  Massenhove        NaN  M Services  527-63-1710   NaN
#
#   STOCK_SYMBOL SUFFIX TIME_ZONE TITLE
# ...

# %%
pindex = person_df.set_index('COMPANY')
cindex = company_df.set_index('COMPANY')

pcmerge = pd.merge(pindex, cindex, how = 'left', on=['COUNTRY_CODE', 'ADDRESS'], left_index= True, right_index = True)
pcmerge.head(3)
# Out:
#                               FIRST_NAME  LAST_NAME  \
# COMPANY
# Abbott, Rodriguez and Schmitt      Haley  Craisford
# Abbott, Rodriguez and Schmitt       Anna      Awton
# Abernathy, Emard and Senger       Alonso    Fitchen
#
#                                                    EMAIL GENDER SUFFIX TITLE  \
# COMPANY
# Abbott, Rodriguez and Schmitt  hcraisford9z@facebook.com      M    NaN    Dr
# Abbott, Rodriguez and Schmitt           aawtonmg@cmu.edu      F    NaN    Ms
# Abernathy, Emard and Senger            afitchenb@nba.com      M    NaN   NaN
#
#                                             ADDRESS  DEPARTMENT  \
# COMPANY
# Abbott, Rodriguez and Schmitt      141 Schurz Place    Training
# Abbott, Rodriguez and Schmitt  63776 Lakeland Plaza  Accounting
# Abernathy, Emard and Senger     05 Mandrake Parkway       Sales
#
#                                                   BITCOIN_ADDRESS  \
# COMPANY
# Abbott, Rodriguez and Schmitt  1CzbeXKiKSbUJjeEYY9WbgjLBTMQ65rEwJ
# ...

# %%
pcmerge = pd.merge(pindex, company_df, how = 'outer', left_on = True, right_on = ['COMPANY']).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-378-df9e59b699fc> in <module>
# ----> 1 pcmerge = pd.merge(pindex, company_df, how = 'outer', left_on = True, right_on = ['COMPANY']).head()
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      80         copy=copy,
#      81         indicator=indicator,
# ---> 82         validate=validate,
#      83     )
#      84     return op.get_result()
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
# ...

# %%
mepec = pd.merge(person_df, company_df, how='left', on='COMPANY')
mepec.head()
mepec[(mepec['FIRST_NAME'] == 'Grethel') & (mepec['LAST_NAME'] == 'Boyce')][['DEPARTMENT', 'COMPANY']]
# Out:
#    DEPARTMENT                      COMPANY
# 1  Accounting  Boehm, VonRueden and Turner

# %%
vbo = transact_df
vbo = vbo[~vbo['CATEGORY'].isna()]  #grabbing everything from vbo that is not na
vbo.head()
# Out:
#                       BITCOIN_ADDRESS    AMOUNT         DATE         TIME  \
# 0  13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A  €8605,56  19-Oct-2020  11:12:56 PM
# 2  12kiq1UUw6aBgnGZBMFZaW7hDbH51uA4A6  €9984,66  26-Nov-2020   5:56:19 PM
# 3  1EXyq8wdLhZcDECocKDGZ7aCq6RmETeYJb  €5709,95  03-Jun-2020   7:38:22 PM
# 5  1LEF7hCLDDjRJ4K65h4FnEaYZyepbM7dta  $8248.19  03-Mar-2021          NaN
# 6  1FGcQ9YhRWH8SKGnxp55PzgmYqKZPC9j9A   £614.72  05-Jun-2020  10:38:35 PM
#
#        TIME_ZONE PURCHASE_APP    CATEGORY  TIME_OFFSET
# 0  Europe/Warsaw         Stim       Music         10.0
# 2    Asia/Harbin      Konklab  Industrial          4.0
# 3    Asia/Tehran        Otcom      Beauty         -4.0
# 5  Europe/Athens        Zamit  Industrial         11.0
# 6  Europe/Warsaw      Andalax       Games         10.0

# %%
robo = pd.pivot_table(vbo, values = 'TIME_OFFSET', columns='BITCOIN_ADDRESS', index = 'TIME', aggfunc=np.mean, margins = True)['All']
robo.head()
# Out:
# TIME
# 10:01:12 PM   -8.0
# 10:01:23 PM   -7.0
# 10:02:59 PM    4.0
# 10:04:35 AM   -2.0
# 10:05:51 PM   -6.0
# Name: All, dtype: float64

# %%
tubs = person_df

tubs.head()
# Out:
#   FIRST_NAME   LAST_NAME                        EMAIL GENDER SUFFIX  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
# 3   Marrilee       Burtt              mburtt3@nps.gov      F     Sr
# 4        Ava    Burchett        aburchett4@taobao.com      F    NaN
#
#        TITLE                     ADDRESS                DEPARTMENT  \
# 0         Dr              98557 2nd Pass                  Services
# 1        Rev                7 Marcy Lane                Accounting
# 2  Honorable       57666 Stoughton Court           Human Resources
# 3        NaN             074 Elgar Point  Research and Development
# 4  Honorable  76045 Mockingbird Crossing                  Services
#
#                       BITCOIN_ADDRESS                        COMPANY  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp     Lehner, Willms and McClure
# ...

# %%
tubs.loc[(0, 1), ('EMAIL', 'GENDER')]
# Out:
#                     EMAIL GENDER
# 0  wmassenhove0@about.com      M
# 1        gboyce1@etsy.com      F

# %%
tubs.iloc[[0], [2, 3]]
# Out:
#                     EMAIL GENDER
# 0  wmassenhove0@about.com      M

# %%
tubs.iloc[0:2, 0:2]['LAST_NAME']
# Out:
# 0    Massenhove
# 1         Boyce
# Name: LAST_NAME, dtype: object

# %%
tubs.head()

def gendername(row):
    for ro in row['GENDER']:
        if ro == 'M':
            return 'Male'
        elif ro == 'F':
            return 'Female'
        else:
            return 'Other'

tubs.apply(gendername, axis = 1)
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3      Female
# 4      Female
#         ...
# 995      Male
# 996    Female
# 997      Male
# 998    Female
# 999      Male
# Length: 1000, dtype: object

# %%
def zero(r):
    return 0

tubs.apply(zero)
# Out:
# FIRST_NAME         0
# LAST_NAME          0
# EMAIL              0
# GENDER             0
# SUFFIX             0
# TITLE              0
# ADDRESS            0
# DEPARTMENT         0
# BITCOIN_ADDRESS    0
# COMPANY            0
# SSN                0
# EMPLOYEE_START     0
# COUNTRY_CODE       0
# NEW_COLUMN2        0
# LAST_FOUR          0
# dtype: int64

# %%
tubs.head()

import re

def last_four(data):
    pattern = '\d{3}-\d{2}-(\d{4})'
    results = re.findall(pattern, data['SSN'])
    return results[0]


tubs['LAST_FOUR'] = tubs.apply(last_four, axis = 1)
tubs.head()
# Out:
#   FIRST_NAME   LAST_NAME                        EMAIL GENDER SUFFIX  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
# 3   Marrilee       Burtt              mburtt3@nps.gov      F     Sr
# 4        Ava    Burchett        aburchett4@taobao.com      F    NaN
#
#        TITLE                     ADDRESS                DEPARTMENT  \
# 0         Dr              98557 2nd Pass                  Services
# 1        Rev                7 Marcy Lane                Accounting
# 2  Honorable       57666 Stoughton Court           Human Resources
# 3        NaN             074 Elgar Point  Research and Development
# 4  Honorable  76045 Mockingbird Crossing                  Services
#
#                       BITCOIN_ADDRESS                        COMPANY  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp     Lehner, Willms and McClure
# ...

# %%
for group, frame in tubs.groupby('COMPANY'):
    #print(group, '\n\n')
    #print(frame, '\n\n')
    mask = frame['LAST_FOUR'] == frame['LAST_FOUR'].max()
    v = frame[mask]
    #print(v)

# %%
tubs.groupby('DEPARTMENT').agg({'LAST_FOUR': len})
# Out:
#                           LAST_FOUR
# DEPARTMENT
# Accounting                       87
# Business Development             97
# Engineering                      69
# Human Resources                  89
# Legal                            91
# Marketing                        73
# Product Management               75
# Research and Development         79
# Sales                            84
# Services                         85
# Support                         103
# Training                         68

# %%
tubs.groupby('DEPARTMENT').transform(np.nanmean)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-391-cf5b0dfe086e> in <module>
# ----> 1 tubs.groupby('DEPARTMENT').transform(np.nanmean)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/generic.py in transform(self, func, *args, **kwargs)
#     580             else:
#     581                 # cythonized aggregation and merge
# --> 582                 result = getattr(self, func)(*args, **kwargs)
#     583         else:
#     584             return self._transform_general(func, *args, **kwargs)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1203         try:
#    1204             return self._cython_agg_general(
# -> 1205                 "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1206             )
#    1207         except GroupByError:
#
# ...

# %%
tubs.head()
tubs.rename(columns = {'EMAIL': 'email'}).head()
# Out:
#   FIRST_NAME   LAST_NAME                        email GENDER SUFFIX  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
# 3   Marrilee       Burtt              mburtt3@nps.gov      F     Sr
# 4        Ava    Burchett        aburchett4@taobao.com      F    NaN
#
#        TITLE                     ADDRESS                DEPARTMENT  \
# 0         Dr              98557 2nd Pass                  Services
# 1        Rev                7 Marcy Lane                Accounting
# 2  Honorable       57666 Stoughton Court           Human Resources
# 3        NaN             074 Elgar Point  Research and Development
# 4  Honorable  76045 Mockingbird Crossing                  Services
#
#                       BITCOIN_ADDRESS                        COMPANY  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp     Lehner, Willms and McClure
# ...

# %%
def ssndecider(row):
    if row['LAST_FOUR'] >= 6000:
        row['rank_level'] = 'first_tier'
    elif row['LAST_FOUR'] >= 4000:
        row['rank_level'] = 'second_tier'
    elif row['LAST_FOUR'] >= 0:
        row['rank_level'] = 'third_tier'
    return row

tubs['LAST_FOUR'] = tubs['LAST_FOUR'].astype('int64')
zotubs = tubs.apply(ssndecider, axis = 1)
tubs = zotubs

# %%
tubs.head()
# Out:
#   FIRST_NAME   LAST_NAME                        EMAIL GENDER SUFFIX  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
# 3   Marrilee       Burtt              mburtt3@nps.gov      F     Sr
# 4        Ava    Burchett        aburchett4@taobao.com      F    NaN
#
#        TITLE                     ADDRESS                DEPARTMENT  \
# 0         Dr              98557 2nd Pass                  Services
# 1        Rev                7 Marcy Lane                Accounting
# 2  Honorable       57666 Stoughton Court           Human Resources
# 3        NaN             074 Elgar Point  Research and Development
# 4  Honorable  76045 Mockingbird Crossing                  Services
#
#                       BITCOIN_ADDRESS                        COMPANY  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp     Lehner, Willms and McClure
# ...

# %%
tubs.pivot_table(values = 'LAST_FOUR', index = 'FIRST_NAME', columns = 'rank_level', aggfunc= [np.mean]).head()
# Out:
#                  mean
# rank_level first_tier second_tier third_tier
# FIRST_NAME
# Abbi              NaN         NaN     3524.0
# Abbie             NaN      4001.0        NaN
# Abie              NaN      5113.0        NaN
# Addy           6898.0         NaN        NaN
# Ado               NaN      4144.0        NaN

# %%
tubs.pivot_table(values = 'LAST_FOUR', index = 'FIRST_NAME', columns = 'rank_level', aggfunc= [np.mean, np.max]).head()
# Out:
#                  mean                              amax
# rank_level first_tier second_tier third_tier first_tier second_tier third_tier
# FIRST_NAME
# Abbi              NaN         NaN     3524.0        NaN         NaN     3524.0
# Abbie             NaN      4001.0        NaN        NaN      4001.0        NaN
# Abie              NaN      5113.0        NaN        NaN      5113.0        NaN
# Addy           6898.0         NaN        NaN     6898.0         NaN        NaN
# Ado               NaN      4144.0        NaN        NaN      4144.0        NaN

# %%
o = tubs.pivot_table(values = 'LAST_FOUR', index = 'FIRST_NAME', columns = 'rank_level', aggfunc= [np.mean, np.max], margins = True).tail()
o
# Out:
#                    mean                                           amax  \
# rank_level   first_tier  second_tier   third_tier       All first_tier
# FIRST_NAME
# Zeb         9547.000000          NaN          NaN  9547.000     9547.0
# Zora                NaN          NaN   784.000000   784.000        NaN
# Zorina      9315.000000          NaN          NaN  9315.000     9315.0
# Zorine              NaN  5488.000000          NaN  5488.000        NaN
# All         7952.009828  5031.471204  1942.338308  4978.299     9992.0
#
#
# rank_level second_tier third_tier   All
# FIRST_NAME
# Zeb                NaN        NaN  9547
# Zora               NaN      784.0   784
# Zorina             NaN        NaN  9315
# Zorine          5488.0        NaN  5488
# All             5976.0     3997.0  9992

# %%
o.index
# Out:
# Index(['Zeb', 'Zora', 'Zorina', 'Zorine', 'All'], dtype='object', name='FIRST_NAME')

# %%
o.columns
# Out:
# MultiIndex([('mean',  'first_tier'),
#             ('mean', 'second_tier'),
#             ('mean',  'third_tier'),
#             ('mean',         'All'),
#             ('amax',  'first_tier'),
#             ('amax', 'second_tier'),
#             ('amax',  'third_tier'),
#             ('amax',         'All')],
#            names=[None, 'rank_level'])

# %%
o.loc[:, 'mean']
# Out:
# rank_level   first_tier  second_tier   third_tier       All
# FIRST_NAME
# Zeb         9547.000000          NaN          NaN  9547.000
# Zora                NaN          NaN   784.000000   784.000
# Zorina      9315.000000          NaN          NaN  9315.000
# Zorine              NaN  5488.000000          NaN  5488.000
# All         7952.009828  5031.471204  1942.338308  4978.299

# %%
o.loc[:, ('mean', 'first_tier')]
# Out:
# FIRST_NAME
# Zeb       9547.000000
# Zora              NaN
# Zorina    9315.000000
# Zorine            NaN
# All       7952.009828
# Name: (mean, first_tier), dtype: float64

# %%
o.stack()
# Out:
#                                mean    amax
# FIRST_NAME rank_level
# Zeb        first_tier   9547.000000  9547.0
#            All          9547.000000  9547.0
# Zora       third_tier    784.000000   784.0
#            All           784.000000   784.0
# Zorina     first_tier   9315.000000  9315.0
#            All          9315.000000  9315.0
# Zorine     second_tier  5488.000000  5488.0
#            All          5488.000000  5488.0
# All        first_tier   7952.009828  9992.0
#            second_tier  5031.471204  5976.0
#            third_tier   1942.338308  3997.0
#            All          4978.299000  9992.0

# %%
o.stack().index
# Out:
# MultiIndex([(   'Zeb',  'first_tier'),
#             (   'Zeb',         'All'),
#             (  'Zora',  'third_tier'),
#             (  'Zora',         'All'),
#             ('Zorina',  'first_tier'),
#             ('Zorina',         'All'),
#             ('Zorine', 'second_tier'),
#             ('Zorine',         'All'),
#             (   'All',  'first_tier'),
#             (   'All', 'second_tier'),
#             (   'All',  'third_tier'),
#             (   'All',         'All')],
#            names=['FIRST_NAME', 'rank_level'])

# %%
o.unstack()
# Out:
#       rank_level   FIRST_NAME
# mean  first_tier   Zeb           9547.000000
#                    Zora                  NaN
#                    Zorina        9315.000000
#                    Zorine                NaN
#                    All           7952.009828
#       second_tier  Zeb                   NaN
#                    Zora                  NaN
#                    Zorina                NaN
#                    Zorine        5488.000000
#                    All           5031.471204
#       third_tier   Zeb                   NaN
#                    Zora           784.000000
#                    Zorina                NaN
#                    Zorine                NaN
#                    All           1942.338308
#       All          Zeb           9547.000000
#                    Zora           784.000000
#                    Zorina        9315.000000
#                    Zorine        5488.000000
#                    All           4978.299000
# ...

# %%
from datetime import datetime
timedf = transact_df
timedf.head()
# Out:
#                       BITCOIN_ADDRESS    AMOUNT         DATE         TIME  \
# 0  13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A  €8605,56  19-Oct-2020  11:12:56 PM
# 1  1HDSWNybswRtsFFGLFxAQrRzkvssT3NNaR  €2019,11  28-Dec-2020   9:43:06 PM
# 2  12kiq1UUw6aBgnGZBMFZaW7hDbH51uA4A6  €9984,66  26-Nov-2020   5:56:19 PM
# 3  1EXyq8wdLhZcDECocKDGZ7aCq6RmETeYJb  €5709,95  03-Jun-2020   7:38:22 PM
# 4  15mp1C8hQeZ8gU5cqT61YBevptAtsjdWZQ  £5149.41  18-Sep-2020   8:57:58 PM
#
#        TIME_ZONE PURCHASE_APP    CATEGORY  TIME_OFFSET
# 0  Europe/Warsaw         Stim       Music         10.0
# 1  Asia/Shanghai     Treeflex         NaN         -3.0
# 2    Asia/Harbin      Konklab  Industrial          4.0
# 3    Asia/Tehran        Otcom      Beauty         -4.0
# 4    Europe/Kiev      Veribet         NaN          2.0

# %%
lambdadf = transact_df
lambdadf

lambdadf['TIME_OFFSET_PLUS_5'] = lambdadf['TIME_OFFSET'].apply(lambda x: x + 5)
lambdadf.head()
# Out:
#                       BITCOIN_ADDRESS    AMOUNT         DATE         TIME  \
# 0  13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A  €8605,56  19-Oct-2020  11:12:56 PM
# 1  1HDSWNybswRtsFFGLFxAQrRzkvssT3NNaR  €2019,11  28-Dec-2020   9:43:06 PM
# 2  12kiq1UUw6aBgnGZBMFZaW7hDbH51uA4A6  €9984,66  26-Nov-2020   5:56:19 PM
# 3  1EXyq8wdLhZcDECocKDGZ7aCq6RmETeYJb  €5709,95  03-Jun-2020   7:38:22 PM
# 4  15mp1C8hQeZ8gU5cqT61YBevptAtsjdWZQ  £5149.41  18-Sep-2020   8:57:58 PM
#
#        TIME_ZONE PURCHASE_APP    CATEGORY  TIME_OFFSET  TIME_OFFSET_PLUS_5
# 0  Europe/Warsaw         Stim       Music         10.0                15.0
# 1  Asia/Shanghai     Treeflex         NaN         -3.0                 2.0
# 2    Asia/Harbin      Konklab  Industrial          4.0                 9.0
# 3    Asia/Tehran        Otcom      Beauty         -4.0                 1.0
# 4    Europe/Kiev      Veribet         NaN          2.0                 7.0

# %%
droptdf = transact_df

droptdf = droptdf.dropna(subset=['CATEGORY'])
droptdf.head()
# Out:
#                       BITCOIN_ADDRESS    AMOUNT         DATE         TIME  \
# 0  13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A  €8605,56  19-Oct-2020  11:12:56 PM
# 2  12kiq1UUw6aBgnGZBMFZaW7hDbH51uA4A6  €9984,66  26-Nov-2020   5:56:19 PM
# 3  1EXyq8wdLhZcDECocKDGZ7aCq6RmETeYJb  €5709,95  03-Jun-2020   7:38:22 PM
# 5  1LEF7hCLDDjRJ4K65h4FnEaYZyepbM7dta  $8248.19  03-Mar-2021          NaN
# 6  1FGcQ9YhRWH8SKGnxp55PzgmYqKZPC9j9A   £614.72  05-Jun-2020  10:38:35 PM
#
#        TIME_ZONE PURCHASE_APP    CATEGORY  TIME_OFFSET  TIME_OFFSET_PLUS_5
# 0  Europe/Warsaw         Stim       Music         10.0                15.0
# 2    Asia/Harbin      Konklab  Industrial          4.0                 9.0
# 3    Asia/Tehran        Otcom      Beauty         -4.0                 1.0
# 5  Europe/Athens        Zamit  Industrial         11.0                16.0
# 6  Europe/Warsaw      Andalax       Games         10.0                15.0

# %%
droptdf.groupby('CATEGORY')['TIME_OFFSET'].transform(len)
# Out:
# 0      33.0
# 2      32.0
# 3      24.0
# 5      32.0
# 6      22.0
#        ...
# 654    31.0
# 655    24.0
# 656    26.0
# 657    32.0
# 658    29.0
# Name: TIME_OFFSET, Length: 540, dtype: float64

# %%
droptdf[['PURCHASE_APP', 'AMOUNT']].head()
# Out:
#   PURCHASE_APP    AMOUNT
# 0         Stim  €8605,56
# 2      Konklab  €9984,66
# 3        Otcom  €5709,95
# 5        Zamit  $8248.19
# 6      Andalax   £614.72

# %%
droptdf[['PURCHASE_APP', 'AMOUNT']].dropna().head()
# Out:
#   PURCHASE_APP    AMOUNT
# 0         Stim  €8605,56
# 2      Konklab  €9984,66
# 3        Otcom  €5709,95
# 5        Zamit  $8248.19
# 6      Andalax   £614.72

# %%
inception = transact_df
inception.head()
# Out:
#                       BITCOIN_ADDRESS    AMOUNT         DATE         TIME  \
# 0  13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A  €8605,56  19-Oct-2020  11:12:56 PM
# 1  1HDSWNybswRtsFFGLFxAQrRzkvssT3NNaR  €2019,11  28-Dec-2020   9:43:06 PM
# 2  12kiq1UUw6aBgnGZBMFZaW7hDbH51uA4A6  €9984,66  26-Nov-2020   5:56:19 PM
# 3  1EXyq8wdLhZcDECocKDGZ7aCq6RmETeYJb  €5709,95  03-Jun-2020   7:38:22 PM
# 4  15mp1C8hQeZ8gU5cqT61YBevptAtsjdWZQ  £5149.41  18-Sep-2020   8:57:58 PM
#
#        TIME_ZONE PURCHASE_APP    CATEGORY  TIME_OFFSET  TIME_OFFSET_PLUS_5
# 0  Europe/Warsaw         Stim       Music         10.0                15.0
# 1  Asia/Shanghai     Treeflex         NaN         -3.0                 2.0
# 2    Asia/Harbin      Konklab  Industrial          4.0                 9.0
# 3    Asia/Tehran        Otcom      Beauty         -4.0                 1.0
# 4    Europe/Kiev      Veribet         NaN          2.0                 7.0

# %%
(inception.where(inception['PURCHASE_APP'] == 'Stim').dropna().set_index('CATEGORY').rename(columns={'AMOUNT': 'FOREIGN_AMOUNT'}))
# Out:
#                                BITCOIN_ADDRESS FOREIGN_AMOUNT         DATE  \
# CATEGORY
# Music       13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A       €8605,56  19-Oct-2020
# Jewelery    12kiq1UUw6aBgnGZBMFZaW7hDbH51uA4A6       £7841.76  21-Oct-2020
# Jewelery    1EXyq8wdLhZcDECocKDGZ7aCq6RmETeYJb       £2984.91  22-Jan-2021
# Garden      1Eyu1aw76p4m8k48uUs5cvkqaPyvfHPsQi       $9583.77  08-Sep-2020
# Jewelery    13Ledy6KT2rVTqwEJXQL9cNeDXnhcDhvbS       €8468,76  03-Nov-2020
# Automotive  18UZKGyrA2JxSgjCghfyJgmm2AkzhD5iYZ       ¥4685.26  03-Jun-2020
# Tools       1B9rWdX9kBgXa6vVP3SGduyZR7CxyYjsno       ¥9461.72  25-Oct-2020
# Outdoors    1MrAnuZ1RA9nRrNd41CeWMLA74hyph4Wpz       $9867.16  16-Aug-2020
# Computers   1FsYEber3L11W7UWSrtbGrzNuzTxt9xQa8       €6504,66  17-Nov-2020
#
#                    TIME           TIME_ZONE PURCHASE_APP  TIME_OFFSET  \
# CATEGORY
# Music       11:12:56 PM       Europe/Warsaw         Stim         10.0
# ...

# %%
inception.head()
inception['TIME_OFFSET_PLUS_10'] = inception['TIME_OFFSET'].apply(lambda x: x + 10)
inception.head()
# Out:
#                       BITCOIN_ADDRESS    AMOUNT         DATE         TIME  \
# 0  13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A  €8605,56  19-Oct-2020  11:12:56 PM
# 1  1HDSWNybswRtsFFGLFxAQrRzkvssT3NNaR  €2019,11  28-Dec-2020   9:43:06 PM
# 2  12kiq1UUw6aBgnGZBMFZaW7hDbH51uA4A6  €9984,66  26-Nov-2020   5:56:19 PM
# 3  1EXyq8wdLhZcDECocKDGZ7aCq6RmETeYJb  €5709,95  03-Jun-2020   7:38:22 PM
# 4  15mp1C8hQeZ8gU5cqT61YBevptAtsjdWZQ  £5149.41  18-Sep-2020   8:57:58 PM
#
#        TIME_ZONE PURCHASE_APP    CATEGORY  TIME_OFFSET  TIME_OFFSET_PLUS_5  \
# 0  Europe/Warsaw         Stim       Music         10.0                15.0
# 1  Asia/Shanghai     Treeflex         NaN         -3.0                 2.0
# 2    Asia/Harbin      Konklab  Industrial          4.0                 9.0
# 3    Asia/Tehran        Otcom      Beauty         -4.0                 1.0
# 4    Europe/Kiev      Veribet         NaN          2.0                 7.0
#
#    TIME_OFFSET_PLUS_10
# 0                 20.0
# ...

# %%
inception['TIME_OFFSET_PLUS_10'].groupby
# Out:
# <bound method NDFrame.groupby of 0      20.0
# 1       7.0
# 2      14.0
# 3       6.0
# 4      12.0
#        ...
# 655    19.0
# 656     7.0
# 657    12.0
# 658    12.0
# 659     NaN
# Name: TIME_OFFSET_PLUS_10, Length: 660, dtype: float64>

# %%
df=pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
                index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 
                       'ok', 'ok', 'ok', 'poor', 'poor'],
               columns=["Grades"])
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
df.dtypes
# Out:
# Grades    object
# dtype: object

# %%
df['Grades'].astype('category').head()
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %% [markdown]
# Find the ratios of male to females working in each industry (including a category for those that are unemployed, which we will consider to be the case if the company they work for is not in the list of companies). Include only employees that have an email domain ending in .com in your analysis. If there are only male employees, return the value np.inf.

# %%
display(person_df.head(3))
display(company_df.head(3))
# Out:
#   FIRST_NAME   LAST_NAME                        EMAIL GENDER SUFFIX  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
#
#        TITLE                ADDRESS       DEPARTMENT  \
# 0         Dr         98557 2nd Pass         Services
# 1        Rev           7 Marcy Lane       Accounting
# 2  Honorable  57666 Stoughton Court  Human Resources
#
#                       BITCOIN_ADDRESS                      COMPANY  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp   Lehner, Willms and McClure
# 1  18c1EisbFW7PrRyXoZcztY2oRUuUcnJ2hK  Boehm, VonRueden and Turner
# 2  1DuQgLuydME3HtXrYtDm6xk8agNqozhzs9     Harris, Abbott and O'Kon
#
#            SSN       EMPLOYEE_START COUNTRY_CODE        NEW_COLUMN2  LAST_FOUR
# 0  527-63-1710  2021-02-02 03:48:49           ID         M Services       1710
# ...

# %%
#dataframes used = person_df & company_df

#merge dataframes
newmerged = pd.merge(person_df, company_df)

# %%
inception.head()
# Out:
#                       BITCOIN_ADDRESS    AMOUNT         DATE         TIME  \
# 0  13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A  €8605,56  19-Oct-2020  11:12:56 PM
# 1  1HDSWNybswRtsFFGLFxAQrRzkvssT3NNaR  €2019,11  28-Dec-2020   9:43:06 PM
# 2  12kiq1UUw6aBgnGZBMFZaW7hDbH51uA4A6  €9984,66  26-Nov-2020   5:56:19 PM
# 3  1EXyq8wdLhZcDECocKDGZ7aCq6RmETeYJb  €5709,95  03-Jun-2020   7:38:22 PM
# 4  15mp1C8hQeZ8gU5cqT61YBevptAtsjdWZQ  £5149.41  18-Sep-2020   8:57:58 PM
#
#        TIME_ZONE PURCHASE_APP    CATEGORY  TIME_OFFSET  TIME_OFFSET_PLUS_5  \
# 0  Europe/Warsaw         Stim       Music         10.0                15.0
# 1  Asia/Shanghai     Treeflex         NaN         -3.0                 2.0
# 2    Asia/Harbin      Konklab  Industrial          4.0                 9.0
# 3    Asia/Tehran        Otcom      Beauty         -4.0                 1.0
# 4    Europe/Kiev      Veribet         NaN          2.0                 7.0
#
#    TIME_OFFSET_PLUS_10
# 0                 20.0
# ...

# %%
inceptionx = transact_df
inceptionx.head()
inceptionx['TIME'] = pd.to_datetime(inceptionx['TIME'])
inceptionx = inceptionx.set_index('TIME')
inceptionx = inceptionx.resample('M').mean()['TIME_OFFSET']
inceptionx
# Out:
# TIME
# 2021-03-31    0.202749
# Name: TIME_OFFSET, dtype: float64

# %%
inception
# Out:
#                         BITCOIN_ADDRESS    AMOUNT         DATE  \
# 0    13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A  €8605,56  19-Oct-2020
# 1    1HDSWNybswRtsFFGLFxAQrRzkvssT3NNaR  €2019,11  28-Dec-2020
# 2    12kiq1UUw6aBgnGZBMFZaW7hDbH51uA4A6  €9984,66  26-Nov-2020
# 3    1EXyq8wdLhZcDECocKDGZ7aCq6RmETeYJb  €5709,95  03-Jun-2020
# 4    15mp1C8hQeZ8gU5cqT61YBevptAtsjdWZQ  £5149.41  18-Sep-2020
# ..                                  ...       ...          ...
# 655  1Gyf2xz1SAJmtz7H9DVHLfk72arD434SSE  ¥1900.64  03-Dec-2020
# 656  12VrC5atYzdAJjzyZXQ7GxeyxCi56bZw71   €238,15  07-Oct-2020
# 657  1B3TDkUvRXdVmu1Nan35qVKtXuj2rY4Tr7  ¥6550.33  16-Oct-2020
# 658   1JExYVkQH17mjs6y42onSSBTGELymH6GL  £1379.11  15-Oct-2020
# 659  1Ep9iBpAqiupY3r81yAKiNpJLg4LN665ML   ¥102.83  31-Aug-2020
#
#                    TIME          TIME_ZONE PURCHASE_APP     CATEGORY  \
# 0   2021-03-19 23:12:56      Europe/Warsaw         Stim        Music
# ...

# %% [markdown]
# Find the ratios of male to females working in each industry (including a category for those that are unemployed, which we will consider to be the case if the company they work for is not in the list of companies). Include only employees that have an email domain ending in .com in your analysis. If there are only male employees, return the value np.inf.

# %%
display(person_df.head(1))
display(company_df.head(1))
# Out:
#   FIRST_NAME   LAST_NAME                   EMAIL GENDER SUFFIX TITLE  \
# 0      Weber  Massenhove  wmassenhove0@about.com      M    NaN    Dr
#
#           ADDRESS DEPARTMENT                     BITCOIN_ADDRESS  \
# 0  98557 2nd Pass   Services  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp
#
#                       COMPANY          SSN       EMPLOYEE_START COUNTRY_CODE  \
# 0  Lehner, Willms and McClure  527-63-1710  2021-02-02 03:48:49           ID
#
#   NEW_COLUMN2  LAST_FOUR
# 0  M Services       1710
#                   ADDRESS          COMPANY MARKET_CAP                INDUSTRY  \
# 0  74409 La Follette Hill  Botsford-Dooley     $3.32B  Oil Refining/Marketing
#
#   STATE COUNTRY COUNTRY_CODE STOCK_SYMBOL    TIME_ZONE
# 0   NaN  Taiwan           TW          BCO  Asia/Taipei

# %%
import re

pcdf = person_df

def emailer(df):
    pattern = r'.+@.+.\com'
    results = re.findall(pattern, df)
    if results == True:
        return True
    else:
        return False
    
pcdf['com'] = pcdf['EMAIL'].apply(emailer)
pcdf

#pcdf = pd.merge(person_df, company_df, how = 'left', on=['COMPANY', 'COUNTRY_CODE'])
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-424-8bb74241657c> in <module>
#      11         return False
#      12
# ---> 13 pcdf['com'] = pcdf['EMAIL'].apply(emailer)
#      14 pcdf
#      15
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4036             else:
#    4037                 values = self.astype(object).values
# -> 4038                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4039
#    4040         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-424-8bb74241657c> in emailer(df)
#       5 def emailer(df):
#       6     pattern = r'.+@.+.\com'
# ----> 7     results = re.findall(pattern, df)
#       8     if results == True:
#       9         return True
#
# ...

# %%
dtdf = transact_df
dtdf.head()
# Out:
#                       BITCOIN_ADDRESS    AMOUNT         DATE  \
# 0  13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A  €8605,56  19-Oct-2020
# 1  1HDSWNybswRtsFFGLFxAQrRzkvssT3NNaR  €2019,11  28-Dec-2020
# 2  12kiq1UUw6aBgnGZBMFZaW7hDbH51uA4A6  €9984,66  26-Nov-2020
# 3  1EXyq8wdLhZcDECocKDGZ7aCq6RmETeYJb  €5709,95  03-Jun-2020
# 4  15mp1C8hQeZ8gU5cqT61YBevptAtsjdWZQ  £5149.41  18-Sep-2020
#
#                  TIME      TIME_ZONE PURCHASE_APP    CATEGORY  TIME_OFFSET  \
# 0 2021-03-19 23:12:56  Europe/Warsaw         Stim       Music         10.0
# 1 2021-03-19 21:43:06  Asia/Shanghai     Treeflex         NaN         -3.0
# 2 2021-03-19 17:56:19    Asia/Harbin      Konklab  Industrial          4.0
# 3 2021-03-19 19:38:22    Asia/Tehran        Otcom      Beauty         -4.0
# 4 2021-03-19 20:57:58    Europe/Kiev      Veribet         NaN          2.0
#
#    TIME_OFFSET_PLUS_5  TIME_OFFSET_PLUS_10
# 0                15.0                 20.0
# 1                 2.0                  7.0
# ...

# %%
def main_country(dtdf):
    for row in dtdf['TIME_ZONE']:
        pattern = '(\w+)\W(\w+)'
        result = re.findall(pattern, row)
        display(result)
#         for x in result:
#             return x
dtdf['main_country'] = dtdf['TIME_ZONE'].apply(main_country) 

dtdf.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-426-ec4a3357577c> in <module>
#       6 #         for x in result:
#       7 #             return x
# ----> 8 dtdf['main_country'] = dtdf['TIME_ZONE'].apply(main_country)
#       9
#      10 dtdf.head()
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4036             else:
#    4037                 values = self.astype(object).values
# -> 4038                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4039
#    4040         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-426-ec4a3357577c> in main_country(dtdf)
#       1 def main_country(dtdf):
# ----> 2     for row in dtdf['TIME_ZONE']:
#       3         pattern = '(\w+)\W(\w+)'
# ...

# %%
abc = transact_df
abc.head()
# Out:
#                       BITCOIN_ADDRESS    AMOUNT         DATE  \
# 0  13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A  €8605,56  19-Oct-2020
# 1  1HDSWNybswRtsFFGLFxAQrRzkvssT3NNaR  €2019,11  28-Dec-2020
# 2  12kiq1UUw6aBgnGZBMFZaW7hDbH51uA4A6  €9984,66  26-Nov-2020
# 3  1EXyq8wdLhZcDECocKDGZ7aCq6RmETeYJb  €5709,95  03-Jun-2020
# 4  15mp1C8hQeZ8gU5cqT61YBevptAtsjdWZQ  £5149.41  18-Sep-2020
#
#                  TIME      TIME_ZONE PURCHASE_APP    CATEGORY  TIME_OFFSET  \
# 0 2021-03-19 23:12:56  Europe/Warsaw         Stim       Music         10.0
# 1 2021-03-19 21:43:06  Asia/Shanghai     Treeflex         NaN         -3.0
# 2 2021-03-19 17:56:19    Asia/Harbin      Konklab  Industrial          4.0
# 3 2021-03-19 19:38:22    Asia/Tehran        Otcom      Beauty         -4.0
# 4 2021-03-19 20:57:58    Europe/Kiev      Veribet         NaN          2.0
#
#    TIME_OFFSET_PLUS_5  TIME_OFFSET_PLUS_10
# 0                15.0                 20.0
# 1                 2.0                  7.0
# ...

# %%
abc['TIME'] = pd.to_datetime(abc['TIME'])
abc = abc.set_index('TIME')
abc.head()
# Out:
#                                         BITCOIN_ADDRESS    AMOUNT  \
# TIME
# 2021-03-19 23:12:56  13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A  €8605,56
# 2021-03-19 21:43:06  1HDSWNybswRtsFFGLFxAQrRzkvssT3NNaR  €2019,11
# 2021-03-19 17:56:19  12kiq1UUw6aBgnGZBMFZaW7hDbH51uA4A6  €9984,66
# 2021-03-19 19:38:22  1EXyq8wdLhZcDECocKDGZ7aCq6RmETeYJb  €5709,95
# 2021-03-19 20:57:58  15mp1C8hQeZ8gU5cqT61YBevptAtsjdWZQ  £5149.41
#
#                             DATE      TIME_ZONE PURCHASE_APP    CATEGORY  \
# TIME
# 2021-03-19 23:12:56  19-Oct-2020  Europe/Warsaw         Stim       Music
# 2021-03-19 21:43:06  28-Dec-2020  Asia/Shanghai     Treeflex         NaN
# 2021-03-19 17:56:19  26-Nov-2020    Asia/Harbin      Konklab  Industrial
# 2021-03-19 19:38:22  03-Jun-2020    Asia/Tehran        Otcom      Beauty
# 2021-03-19 20:57:58  18-Sep-2020    Europe/Kiev      Veribet         NaN
#
#                      TIME_OFFSET  TIME_OFFSET_PLUS_5  TIME_OFFSET_PLUS_10
# TIME
# ...

# %%
abc['2021-03-19': '2021-03-19'].resample('H').asfreq()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-436-8ba1cb77fb86> in <module>
# ----> 1 abc['2021-03-19': '2021-03-19'].resample('H').asfreq()
#
# TypeError: 'Timedelta' object is not subscriptable
