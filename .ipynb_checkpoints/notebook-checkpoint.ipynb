# %% [markdown]
# ### Homework 7 and Midterm Data Set
#
# The dataset you will be working with contains 3 separate csv files. Please feel free to duplicate this project into your own space by creating an account linked to your existing GitHub account (or via another login method of your choice).
#
# `EXAM_DATA_COMPANY.csv` contains information about various companies including an address, its market capitalization (or total dollar market value of a company's outstanding shares of stock), the country (and state/province) where this company is headquartered and its corresponding time zone, and the stock ticker symbol.
#
# `EXAM_DATA_PERSON.csv` contains information about employees working at various companies. It includes personal identifying information such as name, email, address, and country of residence (and some demographic data, namely gender). Financial-related information includes their social security number (SSN) and their payroll accounts (which are paid out using Bitcoin, hence the bitcoin addresses). Company-related information includes the employees official start date/time (when they were entered into the system), and the department in which they work.
#
# `EXAM_DATA_TRANSACT.csv` includes a list of transactions (or rather reimbursments) claimed by various individual's accounts. It includes details such as the time the transaction took place, including the time zone and corresponding Coordinated Universal Time (UTC) offset (side note: these do not match real life; just use what is given). The purchase category and name of the application used to conduct the transaction are also listed.

# %%
import pandas as pd
import numpy as np

company_df = pd.read_csv('EXAM_DATA_COMPANY.csv')
person_df = pd.read_csv('EXAM_DATA_PERSON.csv')
transact_df = pd.read_csv('EXAM_DATA_TRANSACT.csv')

# %%
#EXAM_DATA_COMPANY.csv contains information about various companies including an address, its market capitalization (or total dollar market value of a company's outstanding shares of stock), the country (and state/province) where this company is headquartered and its corresponding time zone, and the stock ticker symbol.
company_df.head(2)
# Out:
#                   address                         company market_cap  \
# 0  74409 La Follette Hill                 Botsford-Dooley     $3.32B
# 1        4 Kropf Crossing  Buckridge, Conroy and Nitzsche    $93.98M
#
#                  industry state        country country_code stock_symbol  \
# 0  Oil Refining/Marketing   NaN         Taiwan           TW          BCO
# 1   Major Pharmaceuticals    NY  United States           US         CTIC
#
#           time_zone
# 0       Asia/Taipei
# 1  America/New_York

# %%
#EXAM_DATA_PERSON.csv contains information about employees working at various companies. It includes personal identifying information such as name, email, address, and country of residence (and some demographic data, namely gender). Financial-related information includes their social security number (SSN) and their payroll accounts (which are paid out using Bitcoin, hence the bitcoin addresses). Company-related information includes the employees official start date/time (when they were entered into the system), and the department in which they work.
person_df.head(2)
# Out:
#   first_name   last_name                   email gender suffix title  \
# 0      Weber  Massenhove  wmassenhove0@about.com      M    NaN    Dr
# 1    Grethel       Boyce        gboyce1@etsy.com      F     II   Rev
#
#           address  department                     bitcoin_address  \
# 0  98557 2nd Pass    Services  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp
# 1    7 Marcy Lane  Accounting  18c1EisbFW7PrRyXoZcztY2oRUuUcnJ2hK
#
#                        company          ssn       employee_start country_code
# 0   Lehner, Willms and McClure  527-63-1710  2021-02-02 03:48:49           ID
# 1  Boehm, VonRueden and Turner  696-71-8117  2020-09-17 01:27:03           US

# %%
#EXAM_DATA_TRANSACT.csv includes a list of transactions (or rather reimbursments) claimed by various individual's accounts. It includes details such as the time the transaction took place, including the time zone and corresponding Coordinated Universal Time (UTC) offset (side note: these do not match real life; just use what is given). The purchase category and name of the application used to conduct the transaction are also listed.
transact_df.head(2)
# Out:
#                       bitcoin_address    amount         date         time  \
# 0  13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A  €8605,56  19-Oct-2020  11:12:56 PM
# 1  1HDSWNybswRtsFFGLFxAQrRzkvssT3NNaR  €2019,11  28-Dec-2020   9:43:06 PM
#
#        time_zone purchase_app category  time_offset
# 0  Europe/Warsaw         Stim    Music         10.0
# 1  Asia/Shanghai     Treeflex      NaN         -3.0

# %% [markdown]
# 1. During which hour are there the most transactions? Be sure to take the time zone into consideration (i.e. report everything relative to UTC+0 for instance).

# %%
#establish which csvfile to use

#change date and time to date time format and place as index

# %%
# def transaction_hour(df):
#     df['datetime'] = pd.to_datetime(df['date'] + ' ' + df['time'])
#     df.drop('date', inplace=True, axis = 1)
#     df.drop('time', inplace=True, axis = 1)
#     df['UTC_time'] = (df['time_offset'] + df['datetime'].dt.hour) % 24
#     #df = df.sort_values(df['UTC_time'], ascending = False)
#     return df



# transaction_hour(transact_df).head()

# %% [markdown]
# 2. Generate a list of all individuals working for pharmaceutical companies that have a market capitalization with units measured in the billions.

# %%
#establish which dataframe to use = person_df and company_df
#merge dataframes
mergedf = pd.merge(person_df, company_df, how = 'inner', on=['company', 'country_code'])

#dataframe where only industry is Major Pharmaceuticals
pharmadf = mergedf[mergedf['industry'] == 'Major Pharmaceuticals']

#create a new column deciding who has billions and who doesn't
import re
def billions(row):
    pattern = r'\$\d.\d+B'
    results = re.findall(pattern, row['market_cap'])
    if results:
        return True
    return False
pharmadf['billions'] = pharmadf.apply(billions, axis = 1)

#isolate the rows that have billions as True
pharmadf = pharmadf[pharmadf['billions'] == True]

#isolate the names
pharmadf[['first_name', 'last_name']]
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
#     first_name last_name
# 154     Shayne   Statton

# %% [markdown]
# 3. What is the monthly average number of transactions (processed in Euros) for each purchase app in the transactions dataset? Which app has the - (1) all-time highest, and (2) all-time lowest number of unique users?

# %%
transact_df.head()
# Out:
#                       bitcoin_address    amount         date         time  \
# 0  13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A  €8605,56  19-Oct-2020  11:12:56 PM
# 1  1HDSWNybswRtsFFGLFxAQrRzkvssT3NNaR  €2019,11  28-Dec-2020   9:43:06 PM
# 2  12kiq1UUw6aBgnGZBMFZaW7hDbH51uA4A6  €9984,66  26-Nov-2020   5:56:19 PM
# 3  1EXyq8wdLhZcDECocKDGZ7aCq6RmETeYJb  €5709,95  03-Jun-2020   7:38:22 PM
# 4  15mp1C8hQeZ8gU5cqT61YBevptAtsjdWZQ  £5149.41  18-Sep-2020   8:57:58 PM
#
#        time_zone purchase_app    category  time_offset
# 0  Europe/Warsaw         Stim       Music         10.0
# 1  Asia/Shanghai     Treeflex         NaN         -3.0
# 2    Asia/Harbin      Konklab  Industrial          4.0
# 3    Asia/Tehran        Otcom      Beauty         -4.0
# 4    Europe/Kiev      Veribet         NaN          2.0

# %%
#isolate dataframe to use = transact_df
#isolate amounts that use euros
import re
euros_df = transact_df[(transact_df['amount'].str.match(r'€.+') == True)]

#change index to datetime
euros_df['datetime'] = pd.to_datetime(euros_df['date'] + ' ' + euros_df['time'])
euros_df = euros_df.set_index('datetime').drop(['date', 'time'], axis = 1)

#next we must resample to month


avg_num = euros_df.groupby('purchase_app')


avg_num.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                                         bitcoin_address    amount  \
# datetime
# 2020-10-19 23:12:56  13q3QxRNsksDNdVhRJnQMb8WLxnH2RqW4A  €8605,56
# 2020-12-28 21:43:06  1HDSWNybswRtsFFGLFxAQrRzkvssT3NNaR  €2019,11
# 2020-11-26 17:56:19  12kiq1UUw6aBgnGZBMFZaW7hDbH51uA4A6  €9984,66
# 2020-06-03 19:38:22  1EXyq8wdLhZcDECocKDGZ7aCq6RmETeYJb  €5709,95
# 2020-11-19 18:32:20  1GMonRgcncJDFmYUtZVzqQYKneVscAQ1Fc  €6005,33
# ...                                                 ...       ...
# 2020-08-31 12:48:56  1Len4LzJ8JYd37hGxE3ru6zQM4xoAmp4Dr  €9270,27
# NaT                  1MGP31dRA2SwBeCoqYgS9d6AJjjViGwpfU  €5751,30
# 2020-10-27 02:21:31  1NeVkfGuvsh2QdggwDve93Cb8ipgUhaUfA  €3072,09
# NaT                  16EiidiFKefVNK7NeG42S7uL39JKx7yvbu  €1057,20
# 2020-10-07 11:31:51  12VrC5atYzdAJjzyZXQ7GxeyxCi56bZw71   €238,15
#
#                              time_zone purchase_app    category  time_offset
# datetime
# 2020-10-19 23:12:56      Europe/Warsaw         Stim       Music         10.0
# 2020-12-28 21:43:06      Asia/Shanghai     Treeflex         NaN         -3.0
# 2020-11-26 17:56:19        Asia/Harbin      Konklab  Industrial          4.0
# 2020-06-03 19:38:22        Asia/Tehran        Otcom      Beauty         -4.0
# 2020-11-19 18:32:20    Europe/Belgrade     Aerified         NaN         -5.0
# ...                                ...          ...         ...          ...
# 2020-08-31 12:48:56      Africa/Luanda          Job      Health        -11.0
# NaT                      Europe/Lisbon     Wrapsafe        Kids          2.0
# 2020-10-27 02:21:31      America/Bahia      Konklux        Kids         -8.0
# NaT                       Asia/Jakarta       Latlux      Sports         10.0
# 2020-10-07 11:31:51  Asia/Kuala_Lumpur     Treeflex      Garden         -3.0
#
# [161 rows x 6 columns]

# %%
def avg_transaction(df):
    #df = pd.merge
    #df = df.set_index(pd.to_datetime(df['date']))
    #df.drop('date', inplace = True, axis = 1)
    df = df[(df['amount'].str.match(r'€.+') == True)]
    df['date'] = df['date'] + ' ' + df['time']
    #df['date'] = pd.to_datetime(df['date'])
 
    return df


avg_transaction(transact_df).head()

# %% [markdown]
# 4
# In the file containing information on employees, there are some inconsistencies with column 'title'.
# Create a new column with each employee’s entire name formatted as follows: add a period to the end of
# each title to reflect that it is an abbreviation, and change each "Honorable" title to its proper abbreviation, "Hon."
# Lastly, don’t forget to tack on the suffix if applicable!

# %%
person_df.head()
# Out:
#   first_name   last_name                        email gender suffix  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
# 3   Marrilee       Burtt              mburtt3@nps.gov      F     Sr
# 4        Ava    Burchett        aburchett4@taobao.com      F    NaN
#
#        title                     address                department  \
# 0         Dr              98557 2nd Pass                  Services
# 1        Rev                7 Marcy Lane                Accounting
# 2  Honorable       57666 Stoughton Court           Human Resources
# 3        NaN             074 Elgar Point  Research and Development
# 4  Honorable  76045 Mockingbird Crossing                  Services
#
#                       bitcoin_address                        company  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp     Lehner, Willms and McClure
# 1  18c1EisbFW7PrRyXoZcztY2oRUuUcnJ2hK    Boehm, VonRueden and Turner
# 2  1DuQgLuydME3HtXrYtDm6xk8agNqozhzs9       Harris, Abbott and O'Kon
# 3  12jmLByL7ngA6TLpRPNAtuh7Src7LGhiKn              Feeney-Gusikowski
# 4  1FDyhoQmmcrHXCcWD4cMy7VJCankW1K9R3  Kerluke, Langworth and Spinka
#
#            ssn       employee_start country_code
# 0  527-63-1710  2021-02-02 03:48:49           ID
# 1  696-71-8117  2020-09-17 01:27:03           US
# 2  383-85-6348  2020-10-01 01:30:20           US
# 3  674-80-7976  2020-12-30 18:25:52           PT
# 4  676-58-0954  2021-02-01 23:30:49           BR

# %%
#figure out which file to use = person_df
npdf = person_df

#add period to title column

#create column called full title
npdf['full_title'] = npdf[npdf.apply(npdf['title'] + '. ' + npdf['first_name'] + npdf['last_name'])]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-fbdaac28dafb> in <module>
#       2 npdf = person_df
#       3 #create column called full title
# ----> 4 npdf['full_title'] = npdf[npdf.apply(npdf['title'] + '. ' + npdf['first_name'] + npdf['last_name'])]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6904             kwds=kwds,
#    6905         )
# -> 6906         return op.get_result()
#    6907
#    6908     def applymap(self, func):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     147         # dispatch to agg
#     148         if is_list_like(self.f) or is_dict_like(self.f):
# --> 149             return self.obj.aggregate(self.f, axis=self.axis, *self.args, **self.kwds)
#     150
#     151         # all empty
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in aggregate(self, func, axis, *args, **kwargs)
#    6688         result = None
#    6689         try:
# -> 6690             result, how = self._aggregate(func, axis=axis, *args, **kwargs)
#    6691         except TypeError:
#    6692             pass
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in _aggregate(self, arg, axis, *args, **kwargs)
#    6702             result = result.T if result is not None else result
#    6703             return result, how
# -> 6704         return super()._aggregate(arg, *args, **kwargs)
#    6705
#    6706     agg = aggregate
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     562         elif is_list_like(arg):
#     563             # we require a list, but not an 'str'
# --> 564             return self._aggregate_multiple_funcs(arg, _level=_level, _axis=_axis), None
#     565         else:
#     566             result = None
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/base.py in _aggregate_multiple_funcs(self, arg, _level, _axis)
#     607                 try:
#     608                     colg = self._gotitem(col, ndim=1, subset=obj.iloc[:, index])
# --> 609                     results.append(colg.aggregate(arg))
#     610                     keys.append(col)
#     611                 except (TypeError, DataError):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py in aggregate(self, func, axis, *args, **kwargs)
#    3877         # Validate the axis parameter
#    3878         self._get_axis_number(axis)
# -> 3879         result, how = self._aggregate(func, *args, **kwargs)
#    3880         if result is None:
#    3881
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     562         elif is_list_like(arg):
#     563             # we require a list, but not an 'str'
# --> 564             return self._aggregate_multiple_funcs(arg, _level=_level, _axis=_axis), None
#     565         else:
#     566             result = None
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/base.py in _aggregate_multiple_funcs(self, arg, _level, _axis)
#     592                 try:
#     593                     colg = self._gotitem(obj.name, ndim=1, subset=obj)
# --> 594                     results.append(colg.aggregate(a))
#     595
#     596                     # make sure we find a good name
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py in aggregate(self, func, axis, *args, **kwargs)
#    3877         # Validate the axis parameter
#    3878         self._get_axis_number(axis)
# -> 3879         result, how = self._aggregate(func, *args, **kwargs)
#    3880         if result is None:
#    3881
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     354
#     355         if isinstance(arg, str):
# --> 356             return self._try_aggregate_string_function(arg, *args, **kwargs), None
#     357
#     358         if isinstance(arg, dict):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/base.py in _try_aggregate_string_function(self, arg, *args, **kwargs)
#     323         raise AttributeError(
#     324             "'{arg}' is not a valid function for "
# --> 325             "'{cls}' object".format(arg=arg, cls=type(self).__name__)
#     326         )
#     327
#
# AttributeError: 'Dr. WeberMassenhove' is not a valid function for 'Series' object

# %%
def import_df(df):
    df['new_name'] = df.apply(title_change)
    return df
    
def title_change(row):
    return row['title'] + '. ' + row['first_name'] + row['last_name']

import_df(person_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-163-e7acfbfb561c> in <module>
#       6     return row['title'] + '. ' + row['first_name'] + row['last_name']
#       7
# ----> 8 import_df(person_df)
#
# <ipython-input-163-e7acfbfb561c> in import_df(df)
#       1 def import_df(df):
# ----> 2     df['new_name'] = df.apply(title_change)
#       3     return df
#       4
#       5 def title_change(row):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6904             kwds=kwds,
#    6905         )
# -> 6906         return op.get_result()
#    6907
#    6908     def applymap(self, func):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# <ipython-input-163-e7acfbfb561c> in title_change(row)
#       4
#       5 def title_change(row):
# ----> 6     return row['title'] + '. ' + row['first_name'] + row['last_name']
#       7
#       8 import_df(person_df)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1062         key = com.apply_if_callable(key, self)
#    1063         try:
# -> 1064             result = self.index.get_value(self, key)
#    1065
#    1066             if not is_scalar(result):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4721         k = self._convert_scalar_indexer(k, kind="getitem")
#    4722         try:
# -> 4723             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4724         except KeyError as e1:
#    4725             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: ('title', 'occurred at index first_name')

# %% [markdown]
# 5. incorrect solution

# %%
person_df.head()
# Out:
#   first_name   last_name                        email gender suffix  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
# 3   Marrilee       Burtt              mburtt3@nps.gov      F     Sr
# 4        Ava    Burchett        aburchett4@taobao.com      F    NaN
#
#        title                     address                department  \
# 0         Dr              98557 2nd Pass                  Services
# 1        Rev                7 Marcy Lane                Accounting
# 2  Honorable       57666 Stoughton Court           Human Resources
# 3        NaN             074 Elgar Point  Research and Development
# 4  Honorable  76045 Mockingbird Crossing                  Services
#
#                       bitcoin_address                        company  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp     Lehner, Willms and McClure
# 1  18c1EisbFW7PrRyXoZcztY2oRUuUcnJ2hK    Boehm, VonRueden and Turner
# 2  1DuQgLuydME3HtXrYtDm6xk8agNqozhzs9       Harris, Abbott and O'Kon
# 3  12jmLByL7ngA6TLpRPNAtuh7Src7LGhiKn              Feeney-Gusikowski
# 4  1FDyhoQmmcrHXCcWD4cMy7VJCankW1K9R3  Kerluke, Langworth and Spinka
#
#            ssn       employee_start country_code
# 0  527-63-1710  2021-02-02 03:48:49           ID
# 1  696-71-8117  2020-09-17 01:27:03           US
# 2  383-85-6348  2020-10-01 01:30:20           US
# 3  674-80-7976  2020-12-30 18:25:52           PT
# 4  676-58-0954  2021-02-01 23:30:49           BR

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4b899bc4-47db-49d1-afe8-5e169e10f438' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

# %%
# def employees(person_df):
#     employees = person_df.groupby('department', axis = 1)
#     return employees

# #employees = person_df.groupby('department', axis = 1)#.loc['gender'].value_counts().to_frame(name = 'count').reset_index()

# #x.set_index('department')
# #x = employees[employees['gender'] == "F"]

# #print(x['count'].idxmax())
# employees(person_df.head())

# %%
employees = person_df#.groupby('department')
employees.head(3)

#.loc['gender']
# .value_counts()
# .to_frame(name = 'count')
# .reset_index()
 
# x = employees[gender] == "F"
# x.set_index('department')
# print(x['count'].idxmax())
# Out:
#   first_name   last_name                        email gender suffix  \
# 0      Weber  Massenhove       wmassenhove0@about.com      M    NaN
# 1    Grethel       Boyce             gboyce1@etsy.com      F     II
# 2     Wilmar     Duester  wduester2@deliciousdays.com      M    NaN
#
#        title                address       department  \
# 0         Dr         98557 2nd Pass         Services
# 1        Rev           7 Marcy Lane       Accounting
# 2  Honorable  57666 Stoughton Court  Human Resources
#
#                       bitcoin_address                      company  \
# 0  1Ken4CZmWgkghXJzCjHndpmEUMDtXPnUNp   Lehner, Willms and McClure
# 1  18c1EisbFW7PrRyXoZcztY2oRUuUcnJ2hK  Boehm, VonRueden and Turner
# 2  1DuQgLuydME3HtXrYtDm6xk8agNqozhzs9     Harris, Abbott and O'Kon
#
#            ssn       employee_start country_code
# 0  527-63-1710  2021-02-02 03:48:49           ID
# 1  696-71-8117  2020-09-17 01:27:03           US
# 2  383-85-6348  2020-10-01 01:30:20           US
